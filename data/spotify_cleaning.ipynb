# %% [markdown]
# **Install openpyxl to write to excel file**
#
# pip install openpyxl

# %%
import numpy as np
import pandas as pd
import openpyxl

# %% [markdown]
# **Reading the data file**

# %%
df = pd.read_csv('spotify_data.csv')
df.head()
# Out:
#                  Track ID                       Track Name        Artist Name  \
# 0  3NVGIampibL0YVG3wwaX8G                    Alabama Haint  Penny and Sparrow
# 1  4ahfLYf0VLVVvN3sdOyQN2  HARD LOVE (feat. Lauren Daigle)      NEEDTOBREATHE
# 2  3g61xRaqII8q1wlQDzv550                   Beautiful Soul       Boyce Avenue
# 3  17apvgam6zK9bJ3Mww7JoB          The Best Is Yet To Come         Ben Rector
# 4  6J56Td7qsOpP0YighOsWL6       Misanthropic Drunken Loner        Days N Daze
#
#                                                Album Release Date  Popularity  \
# 0                                      Alabama Haint   2021-10-22          54
# 1  The Shack: Music From and Inspired By the Orig...   2017-02-24          55
# 2                             Cover Sessions, Vol. 4   2017-12-19          67
# 3                            The Best Is Yet To Come   2021-12-10          50
# 4                                    Rogue Taxidermy   2013-08-23          54
#
#       Genre
# 0  acoustic
# 1  acoustic
# 2  acoustic
# 3  acoustic
# 4  acoustic

# %% [markdown]
# **Using pandas dropna() method to analyze and drop rows/columns with Null values in different ways.**

# %%
# drop all those rows which 
# have any 'nan' value in it

df.dropna(inplace = True)

# %%
df.head()
# Out:
#                  Track ID                       Track Name        Artist Name  \
# 0  3NVGIampibL0YVG3wwaX8G                    Alabama Haint  Penny and Sparrow
# 1  4ahfLYf0VLVVvN3sdOyQN2  HARD LOVE (feat. Lauren Daigle)      NEEDTOBREATHE
# 2  3g61xRaqII8q1wlQDzv550                   Beautiful Soul       Boyce Avenue
# 3  17apvgam6zK9bJ3Mww7JoB          The Best Is Yet To Come         Ben Rector
# 4  6J56Td7qsOpP0YighOsWL6       Misanthropic Drunken Loner        Days N Daze
#
#                                                Album Release Date  Popularity  \
# 0                                      Alabama Haint   2021-10-22          54
# 1  The Shack: Music From and Inspired By the Orig...   2017-02-24          55
# 2                             Cover Sessions, Vol. 4   2017-12-19          67
# 3                            The Best Is Yet To Come   2021-12-10          50
# 4                                    Rogue Taxidermy   2013-08-23          54
#
#       Genre
# 0  acoustic
# 1  acoustic
# 2  acoustic
# 3  acoustic
# 4  acoustic

# %%
## storing dtype before converting

b4_conver = df.dtypes

# %% [markdown]
# **Dropping 'Release Date' column**

# %%
#dropping Release Date column
df=df.drop(columns = ['Release Date'])

# %%
df.columns
# Out:
# Index(['Track ID', 'Track Name', 'Artist Name', 'Album', 'Popularity',
#        'Genre'],
#       dtype='object')

# %%
df.head()
# Out:
#                  Track ID                       Track Name        Artist Name  \
# 0  3NVGIampibL0YVG3wwaX8G                    Alabama Haint  Penny and Sparrow
# 1  4ahfLYf0VLVVvN3sdOyQN2  HARD LOVE (feat. Lauren Daigle)      NEEDTOBREATHE
# 2  3g61xRaqII8q1wlQDzv550                   Beautiful Soul       Boyce Avenue
# 3  17apvgam6zK9bJ3Mww7JoB          The Best Is Yet To Come         Ben Rector
# 4  6J56Td7qsOpP0YighOsWL6       Misanthropic Drunken Loner        Days N Daze
#
#                                                Album  Popularity     Genre
# 0                                      Alabama Haint          54  acoustic
# 1  The Shack: Music From and Inspired By the Orig...          55  acoustic
# 2                             Cover Sessions, Vol. 4          67  acoustic
# 3                            The Best Is Yet To Come          50  acoustic
# 4                                    Rogue Taxidermy          54  acoustic

# %% [markdown]
# **Renaming column titles**

# %%
#Renaming columns

columns_dict = {'Track ID': 'track_id',
                'Track Name': 'track_name',
                'Artist Name': 'artist_name',
                'Album': 'album',
                'Genre': 'genre',
                'Popularity': 'popularity_score'    
                }

df = df.rename(columns= columns_dict)
df.columns
# Out:
# Index(['track_id', 'track_name', 'artist_name', 'album', 'popularity_score',
#        'genre'],
#       dtype='object')

# %%
df.head()
# Out:
#                  track_id                       track_name        artist_name  \
# 0  3NVGIampibL0YVG3wwaX8G                    Alabama Haint  Penny and Sparrow
# 1  4ahfLYf0VLVVvN3sdOyQN2  HARD LOVE (feat. Lauren Daigle)      NEEDTOBREATHE
# 2  3g61xRaqII8q1wlQDzv550                   Beautiful Soul       Boyce Avenue
# 3  17apvgam6zK9bJ3Mww7JoB          The Best Is Yet To Come         Ben Rector
# 4  6J56Td7qsOpP0YighOsWL6       Misanthropic Drunken Loner        Days N Daze
#
#                                                album  popularity_score  \
# 0                                      Alabama Haint                54
# 1  The Shack: Music From and Inspired By the Orig...                55
# 2                             Cover Sessions, Vol. 4                67
# 3                            The Best Is Yet To Come                50
# 4                                    Rogue Taxidermy                54
#
#       genre
# 0  acoustic
# 1  acoustic
# 2  acoustic
# 3  acoustic
# 4  acoustic

# %% [markdown]
# **Removing character '-' from column 'genre'**

# %%
#GENRE

""""
1.) Remove special characters from words. (e.g. “alt-rock” needs to have the “-” removed). 
(This step is contingent based upon the genres we choose)

2.)Remove foreign characters(step may be unnecessary depending on the genre choice)

3.)Already lowercase, no additional cleaning necessary
""""

# %%
df['genre']
# Out:
# 0          acoustic
# 1          acoustic
# 2          acoustic
# 3          acoustic
# 4          acoustic
#            ...
# 2821    world-music
# 2822    world-music
# 2823    world-music
# 2824    world-music
# 2825    world-music
# Name: genre, Length: 2826, dtype: object

# %%
df['genre'] = df['genre'].str.replace('-','', regex = False)
df['genre'] = df['genre'].str.strip()

# %%
df['genre']
# Out:
# 0         acoustic
# 1         acoustic
# 2         acoustic
# 3         acoustic
# 4         acoustic
#            ...
# 2821    worldmusic
# 2822    worldmusic
# 2823    worldmusic
# 2824    worldmusic
# 2825    worldmusic
# Name: genre, Length: 2826, dtype: object

# %%
df.head(10)
# Out:
#                  track_id                       track_name        artist_name  \
# 0  3NVGIampibL0YVG3wwaX8G                    Alabama Haint  Penny and Sparrow
# 1  4ahfLYf0VLVVvN3sdOyQN2  HARD LOVE (feat. Lauren Daigle)      NEEDTOBREATHE
# 2  3g61xRaqII8q1wlQDzv550                   Beautiful Soul       Boyce Avenue
# 3  17apvgam6zK9bJ3Mww7JoB          The Best Is Yet To Come         Ben Rector
# 4  6J56Td7qsOpP0YighOsWL6       Misanthropic Drunken Loner        Days N Daze
# 5  0ngtyvPUKR4YTtkVKvZP02                            Dream      Priscilla Ahn
# 6  14J3PO0VnhtcRa31r7Aj1L         I Could Not Ask for More       Edwin McCain
# 7  60S0LkuUyzHzX29KWew1a6                       Moon River          JJ Heller
# 8  2SZDu4esDLUISRnpYQE17b       I'll Be - Acoustic Version       Edwin McCain
# 9  2bN0VoXCagktb6yAi9942I                  Best I Ever Had       Gavin DeGraw
#
#                                                album  popularity_score  \
# 0                                      Alabama Haint                54
# 1  The Shack: Music From and Inspired By the Orig...                55
# 2                             Cover Sessions, Vol. 4                67
# 3                            The Best Is Yet To Come                50
# 4                                    Rogue Taxidermy                54
# 5                                         A Good Day                57
# 6                                          Messenger                59
# 7                             I Dream of You, Vol. 2                60
# 8                                          Messenger                61
# 9                                        Make A Move                56
#
#       genre
# 0  acoustic
# 1  acoustic
# 2  acoustic
# 3  acoustic
# 4  acoustic
# 5  acoustic
# 6  acoustic
# 7  acoustic
# 8  acoustic
# 9  acoustic

# %% [markdown]
# **Writing dataframe to new csv and excel file**

# %%
df.to_csv('clean_spotify.csv', index = False, encoding = 'utf-8')
df.to_excel('clean_spotify.xlsx', index = False)
