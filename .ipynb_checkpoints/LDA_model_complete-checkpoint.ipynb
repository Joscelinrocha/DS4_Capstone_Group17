# %%
## Joscelin is following these steps: https://github.com/Sandeep-Panchal/Topic-Modeling-with-LDA/blob/master/Topic-Modeling-IPYNB/Topic%20Modeling%20with%20LDA.ipynb

import numpy as np
import pandas as pd
import random

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/twitter_data_clean_final.csv')
df = df.loc[:,["user_id","user_bio","tokens","state","region"]]
df.dropna(inplace=True)
df
# deep copy to avoid override of the original dataframe
import copy

df_new = copy.deepcopy(df)

to_remove = ['act', 'angeles','car', 'card', 'acct','acab','ada','admin','aew','age', 'ain', 'aka','alt','alum', 'angeleno', 'answer','antonio','app',
            'area','ask','atl', 'ben', 'brady','brandon', 'chair','circle','clue','collab','com', 'come', 'day', 'dedicate',
            'dev', 'dms','diego', 'dont', 'dot', 'drive', 'driver', 'eat', 'email', 'eth', 'feed', 'form', 'fsu', 'gas', 'giants',
            'google', 'group', 'hair', 'half','harris', 'head','hear','hip', 'hire','hit','hiv','holder','host', 'hold',
            'huge', 'ill', 'info', 'inquire','inquires', 'internet', 'investor', 'investors', 'jeff', 'jack', 'job', 'joe',
            'john', 'join', 'know', 'las', 'lake', ' let', 'lil', 'line', 'link','listen', 'little', 'llc', 'los', 'main', 
            'meet', 'member', 'miles', 'mma', 'multi','near', 'need', 'nice', 'nominate', 'non', 'nut', 'okay', 'open', 
            'order', 'padres', 'page', 'park', 'pin', 'plug', 'print','provide', 'providence', 'ram', 'sag', 'say', 'sell', 'set', 
            'stl','sth','sub', 'syndication', 'tell', 'tony', 'true', 'try', 'tryna', 'type', 'typos', 'usa', 'use', 'valley', 
            'verse', 'view', 'way', 'year', 'years', 'yrs']


            
def stringToList(string):
    listRes = list(string.split(" "))
    return listRes

ls_tokens = []  

for cell in df_new.tokens: 
    cell = stringToList(cell)
    ls_tokens.append(cell)
    


for cell in ls_tokens: 
    for word in list(cell):
        if word in to_remove:
            cell.remove(word)
            
df_new['ls_tokens'] = ls_tokens

df_new['new_tokens'] = [' '.join(map(str, l)) for l in df_new['ls_tokens']]
df_new
# Out:
#            user_id                                           user_bio  \
# 0     1.180000e+18  I'm a nerdy guy who loves art, music, wrestlin...
# 1     1.440000e+18  No worries Lil Ms Sunshine cause I don't mess ...
# 2     1.219720e+08  I am a huge sports and music fan. I graduated ...
# 3     1.390000e+18  This is not, nor endorsed by, any Government E...
# 4     2.349053e+07  I'm a writer and a cult film fanatic who loves...
# ...            ...                                                ...
# 1723  2.961228e+08  Christian. Husband. Father. Ph.D. Candidate @B...
# 1724  8.800000e+17  MarTech, MBA, Foodie, Bilingual, Soccer, Boxin...
# 1725  1.153059e+09  streams occasionally, will choose race cars ov...
# 1726  2.432869e+08  Enjoy the practical wisdom of daily life. Prom...
# 1727  2.159799e+09                                    glass half full
#
#                                                  tokens state     region  \
# 0          nerdy guy love art music wrestle comics poly    OH    Midwest
# 1     worry lil sunshine cause mess woman moon civil...    PA  Northeast
# 2     huge sport music fan graduate regis university...    CO       West
# 3     endorse government entity project guarantee wa...    WA       West
# 4                writer cult film fanatic love politics    UT       West
# ...                                                 ...   ...        ...
# 1723  christian husband father candidate mosquito re...    OH    Midwest
# 1724  martech mba foodie bilingual soccer box gamer ...    CA       West
# 1725  stream occasionally choose race cars important...    KY      South
# 1726  enjoy practical wisdom daily life promote trut...    AZ  Southwest
# 1727                                         glass half    MO    Midwest
#
#                                               ls_tokens  \
# 0     [nerdy, guy, love, art, music, wrestle, comics...
# 1     [worry, sunshine, cause, mess, woman, moon, ci...
# 2     [sport, music, fan, graduate, regis, universit...
# 3     [endorse, government, entity, project, guarant...
# 4         [writer, cult, film, fanatic, love, politics]
# ...                                                 ...
# 1723  [christian, husband, father, candidate, mosqui...
# 1724  [martech, mba, foodie, bilingual, soccer, box,...
# 1725  [stream, occasionally, choose, race, cars, imp...
# 1726  [enjoy, practical, wisdom, daily, life, promot...
# 1727                                            [glass]
#
#                                              new_tokens
# 0          nerdy guy love art music wrestle comics poly
# 1     worry sunshine cause mess woman moon civil rig...
# 2     sport music fan graduate regis university live...
# 3     endorse government entity project guarantee wa...
# 4                writer cult film fanatic love politics
# ...                                                 ...
# 1723  christian husband father candidate mosquito re...
# 1724  martech mba foodie bilingual soccer box gamer ...
# 1725  stream occasionally choose race cars important...
# 1726  enjoy practical wisdom daily life promote trut...
# 1727                                              glass
#
# [1644 rows x 7 columns]

# %%
# importing TFIDF vectorizer
from sklearn.feature_extraction.text import CountVectorizer

# creating an instance
cv = CountVectorizer(max_df = 0.90, min_df = 3, stop_words = 'english')

# fit and transform the text data
cv_fit = cv.fit_transform(df_new.new_tokens)

print('\nShape of the sparse matrix\n')
cv_fit
# Out:
# Shape of the sparse matrix
# <1644x823 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6333 stored elements in Compressed Sparse Row format>

# %%
# importing Latent Dirichlet Allocation library
from sklearn.decomposition import LatentDirichletAllocation

# creating an instance for LDA
lda = LatentDirichletAllocation(n_components = 55, random_state = 3)

# %%
# %%time

print('Fitting the vectorizer with the LDA')

lda.fit(cv_fit)
# Out:
# Fitting the vectorizer with the LDA
# CPU times: user 3.86 s, sys: 95.9 ms, total: 3.96 s
# Wall time: 4.36 s
# LatentDirichletAllocation(n_components=55, random_state=3)

# %%
print('Number of topic:', len(lda.components_))
print('Number of column of the lda fit:',len(lda.components_[0]))
cv
# Out:
# Number of topic: 55
# Number of column of the lda fit: 823
# CountVectorizer(max_df=0.9, min_df=3, stop_words='english')

# %%
feature = cv.get_feature_names()

print('Length of feature names:', len(feature))
# Out:
# Length of feature names: 823

# %%
for ind, topic in enumerate(lda.components_):
    print('top 50 words in topic {}'.format(ind))
    print('-'*25)
    top_50 = topic.argsort()[-50:]
    print([feature[i] for i in top_50], '\n\n')
# Out:
# top 50 words in topic 0
# -------------------------
# ['rest', 'black', 'veteran', 'nurse', 'peace', 'miss', 'break', 'beautiful', 'army', 'dog', 'wife', 'chocolate', 'disney', 'marry', 'creative', 'help', 'world', 'grow', 'cat', 'weather', 'fun', 'beach', 'anti', 'lookin', 'dancer', 'retire', 'law', 'write', 'music', 'movies', 'beauty', 'fashion', 'old', 'block', 'read', 'account', 'league', 'god', 'travel', 'good', 'free', 'book', 'american', 'baseball', 'fan', 'shit', 'trump', 'love', 'mom', 'want']
#
#
# top 50 words in topic 1
# -------------------------
# ['author', 'fox', 'buy', 'kid', 'travel', 'base', 'club', 'hop', 'best', 'city', 'win', 'sport', 'award', 'anchor', 'guy', 'lover', 'family', 'include', 'man', 'vet', 'make', 'husband', 'media', 'activist', 'writer', 'free', 'spiritual', 'check', 'thinker', 'trade', 'mind', 'blogger', 'big', 'american', 'nyc', 'tire', 'enthusiast', 'pussy', 'small', 'film', 'team', 'baseball', 'coach', 'play', 'photography', 'volunteer', 'soul', 'digital', 'truth', 'like']
#
#
# top 50 words in topic 2
# -------------------------
# ['bartender', 'actor', 'sexual', 'post', 'train', 'defense', 'people', 'model', 'custom', 'pansexual', 'cover', 'columbia', 'cash', 'rock', 'single', 'read', 'atlanta', 'twitter', 'free', 'instagram', 'vaxxed', 'painter', 'american', 'market', 'nft', 'metaverse', 'influencer', 'artist', 'web', 'crypto', 'writer', 'original', 'navy', 'political', 'tweet', 'work', 'alumni', 'band', 'wrestle', 'vet', 'photographer', 'teacher', 'design', 'young', 'hunter', 'nba', 'break', 'videos', 'fan', 'news']
#
#
# top 50 words in topic 3
# -------------------------
# ['lookin', 'fuck', 'football', 'lakers', 'graphic', 'cashapp', 'marry', 'city', 'atlanta', 'follow', 'big', 'help', 'male', 'york', 'army', 'strong', 'photography', 'punk', 'democrat', 'advisor', 'girl', 'senior', 'coffee', 'tattoo', 'passion', 'ball', 'baseball', 'trojan', 'class', 'best', 'creative', 'vet', 'fan', 'old', 'restaurant', 'dicks', 'alumnus', 'scene', 'organizer', 'usc', 'politics', 'dog', 'beer', 'account', 'tweet', 'design', 'kentucky', 'progressive', 'professional', 'pizza']
#
#
# top 50 words in topic 4
# -------------------------
# ['drag', 'politics', 'generation', 'proud', 'tweet', 'field', 'dreamer', 'water', 'organizer', 'human', 'profit', 'thinker', 'student', 'public', 'nfl', 'stuff', 'stand', 'sport', 'past', 'founder', 'funny', 'affiliate', 'theme', 'value', 'friends', 'youtuber', 'guild', 'twitch', 'programmer', 'war', 'work', 'ambassador', 'brand', 'like', 'learn', 'scientist', 'teacher', 'musician', 'family', 'sex', 'director', 'health', 'game', 'writer', 'collector', 'american', 'video', 'disable', 'culture', 'instagram']
#
#
# top 50 words in topic 5
# -------------------------
# ['oakland', 'latino', 'photos', 'film', 'speak', 'photography', 'lawyer', 'political', 'musician', 'long', 'smart', 'small', 'run', 'town', 'girl', 'ass', 'junkie', 'hop', 'husband', 'avid', 'singer', 'actor', 'dancer', 'enthusiast', 'peace', 'writer', 'science', 'change', 'paint', 'fast', 'furry', 'judge', 'cover', 'school', 'brother', 'father', 'artist', 'proud', 'book', 'learn', 'burn', 'inspire', 'embrace', 'game', 'build', 'future', 'texas', 'middle', 'like', 'life']
#
#
# top 50 words in topic 6
# -------------------------
# ['learn', 'estate', 'medical', 'founder', 'metal', 'podcast', 'comic', 'favorite', 'oakland', 'east', 'athletics', 'bay', 'available', 'organizer', 'culture', 'world', 'art', 'stuff', 'health', 'jazz', 'speaker', 'deep', 'professor', 'fight', 'instructor', 'music', 'singer', 'lover', 'geek', 'hot', 'philadelphia', 'scorpio', 'sci', 'real', 'science', 'journalist', 'account', 'tweet', 'season', 'south', 'pop', 'writer', 'leo', 'fee', 'educator', 'aries', 'book', 'specialist', 'houston', 'politics']
#
#
# top 50 words in topic 7
# -------------------------
# ['artist', 'aries', 'ass', 'podcaster', 'student', 'author', 'create', 'win', 'award', 'welcome', 'knight', 'like', 'insta', 'tik', 'tok', 'stan', 'wine', 'sweet', 'official', 'woman', 'piece', 'inspire', 'art', 'food', 'focus', 'culture', 'black', 'fan', 'master', 'news', 'travel', 'life', 'cashapp', 'heart', 'success', 'bitch', 'film', 'bring', 'movies', 'book', 'personal', 'tattoo', 'taste', 'writer', 'universe', 'radio', 'let', 'light', 'music', 'producer']
#
#
# top 50 words in topic 8
# -------------------------
# ['enjoy', 'daily', 'think', 'fast', 'dumb', 'ass', 'bear', 'breed', 'family', 'write', 'obsess', 'pan', 'things', 'poly', 'trans', 'player', 'music', 'guy', 'web', 'advocate', 'post', 'grad', 'mean', 'law', 'girl', 'school', 'sex', 'smile', 'break', 'creative', 'opinions', 'life', 'win', 'manager', 'property', 'midwest', 'pay', 'teacher', 'food', 'creator', 'live', 'social', 'american', 'media', 'work', 'self', 'teach', 'fuck', 'good', 'retire']
#
#
# top 50 words in topic 9
# -------------------------
# ['chef', 'pizza', 'regular', 'death', 'award', 'win', 'rise', 'writer', 'feature', 'school', 'daughter', 'photos', 'amaze', 'light', 'tech', 'addict', 'affiliate', 'ravenclaw', 'san', 'star', 'marvel', 'war', 'twitch', 'designer', 'design', 'wrestle', 'click', 'like', 'fear', 'great', 'guitar', 'book', 'owner', 'warriors', 'guy', 'god', 'science', 'production', 'husband', 'old', 'sport', 'fan', 'lead', 'history', 'nerd', 'good', 'long', 'father', 'tweet', 'time']
#
#
# top 50 words in topic 10
# -------------------------
# ['break', 'agent', 'scientist', 'writer', 'doctor', 'license', 'musician', 'family', 'smile', 'choreographer', 'box', 'trainer', 'videographer', 'dad', 'figure', 'collector', 'picture', 'entertainment', 'geek', 'photography', 'marvel', 'father', 'war', 'movies', 'nerd', 'mom', 'girl', 'real', 'vet', 'fighter', 'design', 'guild', 'champion', 'consultant', 'estate', 'service', 'cal', 'club', 'son', 'owner', 'professional', 'democrat', 'retire', 'dance', 'read', 'grandma', 'proud', 'star', 'bear', 'raise']
#
#
# top 50 words in topic 11
# -------------------------
# ['model', 'education', 'expert', 'news', 'post', 'lot', 'bean', 'sad', 'shit', 'industry', 'professionals', 'company', 'independent', 'comic', 'specialize', 'home', 'book', 'foodie', 'dad', 'advocate', 'estate', 'amaze', 'life', 'care', 'real', 'lifestyle', 'blogger', 'sport', 'maker', 'fav', 'story', 'creativity', 'media', 'think', 'big', 'official', 'district', 'creator', 'actor', 'gift', 'opinions', 'cat', 'fan', 'cub', 'crypto', 'stuff', 'respond', 'connecticut', 'nft', 'account']
#
#
# top 50 words in topic 12
# -------------------------
# ['women', 'community', 'wanna', 'paint', 'photography', 'project', 'filmmaker', 'cinema', 'check', 'sales', 'advisor', 'winner', 'place', 'home', 'world', 'advocate', 'better', 'make', 'researcher', 'tree', 'family', 'liberal', 'sense', 'singer', 'cancer', 'teacher', 'tech', 'photographer', 'lover', 'model', 'support', 'nsfw', 'traveler', 'retire', 'creative', 'win', 'award', 'producer', 'inquiries', 'technology', 'love', 'music', 'market', 'musician', 'director', 'manager', 'business', 'creator', 'content', 'follow']
#
#
# top 50 words in topic 13
# -------------------------
# ['nyc', 'resident', 'rule', 'money', 'alumnus', 'husband', 'drink', 'research', 'candidate', 'christian', 'vet', 'self', 'water', 'fitness', 'free', 'film', 'agent', 'cars', 'blm', 'native', 'horror', 'soul', 'sport', 'father', 'brand', 'music', 'fan', 'metal', 'smile', 'sneakers', 'lol', 'partner', 'far', 'punk', 'bad', 'leave', 'place', 'represent', 'look', 'conservative', 'army', 'ball', 'project', 'business', 'nft', 'collector', 'mind', 'enthusiast', 'tweet', 'people']
#
#
# top 50 words in topic 14
# -------------------------
# ['scanner', 'east', 'resident', 'philosophy', 'pop', 'fee', 'automate', 'county', 'politics', 'ninja', 'dreamer', 'friend', 'gamer', 'culture', 'long', 'chef', 'student', 'earth', 'code', 'wine', 'owner', 'learn', 'developer', 'favorite', 'currently', 'today', 'track', 'ones', 'addict', 'journey', 'new', 'traveler', 'welcome', 'design', 'star', 'spur', 'baby', 'marry', 'retire', 'make', 'taste', 'anime', 'husband', 'dad', 'help', 'nerd', 'daddy', 'life', 'cowboys', 'war']
#
#
# top 50 words in topic 15
# -------------------------
# ['partner', 'nsfw', 'tree', 'soul', 'look', 'proud', 'owner', 'film', 'comedian', 'comedy', 'hour', 'photographer', 'shoot', 'peace', 'stand', 'visit', 'information', 'health', 'latest', 'website', 'life', 'god', 'let', 'major', 'opportunities', 'gal', 'unt', 'broncos', 'evil', 'things', 'amaze', 'save', 'detroit', 'animals', 'awesome', 'enjoy', 'gun', 'blue', 'live', 'work', 'vote', 'create', 'growth', 'hate', 'happen', 'senior', 'bless', 'special', 'team', 'account']
#
#
# top 50 words in topic 16
# -------------------------
# ['air', 'house', 'pay', 'healthcare', 'water', 'free', 'marathon', 'usc', 'trojan', 'private', 'sign', 'leave', 'earth', 'die', 'forget', 'talent', 'athlete', 'army', 'ceo', 'real', 'help', 'author', 'veteran', 'coach', 'activist', 'power', 'school', 'team', 'teacher', 'organizer', 'nurse', 'people', 'sunday', 'runner', 'life', 'touch', 'bay', 'deep', 'want', 'engineer', 'watch', 'like', 'stream', 'unmonitored', 'develop', 'contact', 'office', 'national', 'service', 'weather']
#
#
# top 50 words in topic 17
# -------------------------
# ['california', 'ass', 'financial', 'study', 'certify', 'random', 'hot', 'thinker', 'face', 'pretty', 'free', 'knit', 'soft', 'spirit', 'strong', 'onlyfans', 'fun', 'quality', 'beach', 'fitness', 'money', 'relations', 'air', 'amaze', 'person', 'tech', 'class', 'guess', 'cancer', 'retire', 'mean', 'win', 'pan', 'create', 'word', 'currently', 'dad', 'dog', 'irl', 'stay', 'best', 'save', 'play', 'girl', 'joke', 'cashapp', 'life', 'time', 'stage', 'like']
#
#
# top 50 words in topic 18
# -------------------------
# ['cult', 'humanist', 'happily', 'cashapp', 'horror', 'pop', 'buy', 'movies', 'university', 'washington', 'blue', 'advocate', 'social', 'music', 'mean', 'mental', 'impact', 'health', 'lgbtq', 'business', 'owner', 'cat', 'art', 'life', 'creative', 'denver', 'text', 'illustrator', 'marathon', 'rise', 'moon', 'company', 'actor', 'lover', 'enthusiast', 'artist', 'currently', 'chicago', 'work', 'founder', 'dad', 'enjoy', 'everyday', 'athlete', 'transplant', 'comedian', 'native', 'sun', 'twitch', 'affiliate']
#
#
# top 50 words in topic 19
# -------------------------
# ['book', 'nurse', 'series', 'bear', 'designer', 'boston', 'director', 'owner', 'illustrator', 'lifestyle', 'vegas', 'let', 'lgbtq', 'new', 'photography', 'free', 'software', 'cook', 'gun', 'network', 'entrepreneur', 'tech', 'humanity', 'modern', 'culture', 'big', 'connoisseur', 'home', 'consultant', 'block', 'producer', 'phil', 'cause', 'executive', 'ceo', 'enthusiast', 'urban', 'emmy', 'travel', 'talk', 'private', 'entertainment', 'art', 'real', 'estate', 'write', 'win', 'news', 'music', 'currently']
#
#
# top 50 words in topic 20
# -------------------------
# ['official', 'band', 'punk', 'big', 'advice', 'wife', 'storyteller', 'winner', 'emmy', 'dog', 'anchor', 'mother', 'mind', 'travel', 'latest', 'graphics', 'tip', 'programmer', 'leave', 'music', 'insta', 'clean', 'nfts', 'scientist', 'help', 'follow', 'post', 'speak', 'designer', 'new', 'proud', 'friend', 'owner', 'introvert', 'chicago', 'tweet', 'violence', 'enthusiast', 'podcast', 'account', 'news', 'base', 'money', 'events', 'twitter', 'photographer', 'king', 'mom', 'care', 'wanna']
#
#
# top 50 words in topic 21
# -------------------------
# ['feature', 'boy', 'world', 'build', 'dream', 'reality', 'digital', 'partner', 'wake', 'lead', 'guy', 'look', 'nsfw', 'cub', 'bear', 'night', 'founder', 'create', 'war', 'experience', 'currently', 'vegas', 'talk', 'air', 'politics', 'navy', 'technology', 'veteran', 'senior', 'enjoy', 'work', 'video', 'business', 'big', 'photo', 'things', 'people', 'credit', 'consultant', 'tip', 'game', 'ass', 'company', 'star', 'sales', 'bio', 'cash', 'travel', 'free', 'help']
#
#
# top 50 words in topic 22
# -------------------------
# ['alumnus', 'today', 'strong', 'bless', 'self', 'research', 'employer', 'support', 'opinions', 'development', 'lot', 'adventure', 'read', 'history', 'great', 'gift', 'cook', 'city', 'founder', 'nyc', 'florida', 'follow', 'rock', 'roll', 'custom', 'politics', 'work', 'democrat', 'old', 'music', 'football', 'life', 'husband', 'writer', 'real', 'agency', 'liberal', 'dog', 'community', 'spirituality', 'rule', 'ones', 'grand', 'humanity', 'bring', 'crypto', 'save', 'love', 'forever', 'cat']
#
#
# top 50 words in topic 23
# -------------------------
# ['fitness', 'friend', 'fav', 'friends', 'father', 'financial', 'film', 'artist', 'coach', 'sponsor', 'check', 'best', 'counselor', 'biden', 'better', 'major', 'musician', 'disable', 'graphics', 'creator', 'nature', 'update', 'spirit', 'cocktails', 'personal', 'small', 'politics', 'business', 'freedom', 'free', 'owner', 'advocate', 'lover', 'market', 'life', 'shoot', 'stick', 'philosophy', 'cinema', 'youtube', 'liberal', 'traffic', 'like', 'tweet', 'follow', 'rest', 'shop', 'rip', 'worker', 'social']
#
#
# top 50 words in topic 24
# -------------------------
# ['broncos', 'help', 'professionals', 'property', 'run', 'right', 'fan', 'watch', 'washington', 'lifestyle', 'report', 'actor', 'transit', 'seattle', 'entrepreneur', 'specialize', 'husband', 'partner', 'shoot', 'professional', 'hot', 'plant', 'goth', 'metal', 'bitch', 'mom', 'horror', 'enthusiast', 'hoe', 'anime', 'photographer', 'food', 'promoter', 'check', 'truck', 'comedy', 'dude', 'party', 'travel', 'event', 'traffic', 'podcast', 'estate', 'time', 'dog', 'adventure', 'real', 'bio', 'follow', 'photography']
#
#
# top 50 words in topic 25
# -------------------------
# ['stand', 'programmer', 'coffee', 'girl', 'icon', 'credit', 'liberal', 'martial', 'study', 'graphic', 'lgbtq', 'autistic', 'goth', 'politics', 'progressive', 'daily', 'productions', 'wife', 'mom', 'owner', 'blogger', 'winner', 'tattoo', 'audio', 'collector', 'gemini', 'base', 'grammy', 'nyc', 'fan', 'time', 'favorite', 'food', 'emmy', 'cancer', 'style', 'award', 'mixer', 'director', 'rapper', 'lion', 'voice', 'youtube', 'actor', 'producer', 'music', 'arts', 'creative', 'designer', 'engineer']
#
#
# top 50 words in topic 26
# -------------------------
# ['death', 'democrat', 'fight', 'thoughts', 'entrepreneur', 'fear', 'think', 'god', 'person', 'leo', 'wave', 'georgia', 'real', 'forget', 'modern', 'roll', 'dice', 'award', 'journalist', 'report', 'emmy', 'short', 'single', 'proud', 'support', 'friends', 'trump', 'forever', 'play', 'rule', 'denver', 'daily', 'mean', 'visual', 'fox', 'personality', 'conservative', 'best', 'old', 'win', 'student', 'look', 'bartender', 'blue', 'life', 'long', 'good', 'grad', 'boy', 'live']
#
#
# top 50 words in topic 27
# -------------------------
# ['fav', 'humanist', 'humanity', 'teacher', 'composer', 'touch', 'best', 'wife', 'illustrator', 'nfts', 'social', 'probably', 'design', 'outdoors', 'nerd', 'play', 'run', 'women', 'writer', 'director', 'vote', 'dead', 'graphic', 'talk', 'dancer', 'advocate', 'cashapp', 'tattoo', 'male', 'guitar', 'progressive', 'nature', 'partner', 'black', 'like', 'designer', 'brand', 'kill', 'politics', 'guy', 'family', 'reality', 'father', 'ambassador', 'boys', 'poly', 'bad', 'game', 'music', 'man']
#
#
# top 50 words in topic 28
# -------------------------
# ['bitch', 'previously', 'dice', 'roll', 'jesus', 'support', 'buff', 'miami', 'creator', 'fitness', 'sport', 'choreographer', 'tiktok', 'dancer', 'easy', 'private', 'foodie', 'nerd', 'nature', 'gaymer', 'dodgers', 'kings', 'chargers', 'lakers', 'tongue', 'advocate', 'soft', 'heart', 'old', 'southern', 'soul', 'music', 'scorpio', 'long', 'dog', 'vaxxed', 'model', 'trade', 'lord', 'crazy', 'metal', 'mom', 'tweeter', 'nsfw', 'trader', 'junkie', 'movie', 'animal', 'welcome', 'lover']
#
#
# top 50 words in topic 29
# -------------------------
# ['actor', 'future', 'publisher', 'sport', 'bully', 'texas', 'cool', 'people', 'independent', 'respect', 'include', 'art', 'mind', 'thinker', 'food', 'human', 'hour', 'variety', 'city', 'grow', 'big', 'mother', 'joke', 'singer', 'songwriter', 'creator', 'account', 'junkie', 'producer', 'favorite', 'coffee', 'film', 'obsess', 'like', 'stuff', 'baby', 'politics', 'new', 'history', 'psn', 'chef', 'blood', 'music', 'feel', 'follow', 'tiktok', 'record', 'writer', 'write', 'podcast']
#
#
# top 50 words in topic 30
# -------------------------
# ['catch', 'bedroom', 'book', 'podcast', 'base', 'influencer', 'miss', 'publish', 'vegas', 'cool', 'collector', 'nerd', 'anime', 'good', 'gift', 'bad', 'wrestle', 'publisher', 'real', 'run', 'president', 'owner', 'school', 'content', 'manager', 'look', 'daddy', 'music', 'like', 'sound', 'sun', 'dancer', 'nft', 'person', 'raise', 'designer', 'professional', 'regular', 'boston', 'random', 'great', 'connect', 'american', 'game', 'media', 'sign', 'guy', 'creator', 'things', 'photographer']
#
#
# top 50 words in topic 31
# -------------------------
# ['build', 'phd', 'company', 'tech', 'actor', 'proud', 'right', 'grammy', 'mask', 'blue', 'women', 'fear', 'father', 'brother', 'opportunities', 'health', 'financial', 'make', 'xbox', 'lord', 'christ', 'son', 'kid', 'entrepreneur', 'mom', 'dad', 'cat', 'kings', 'houston', 'doctor', 'fan', 'vegan', 'run', 'retire', 'game', 'author', 'jesus', 'lover', 'seattle', 'opinions', 'fanatic', 'engineer', 'geek', 'southern', 'podcaster', 'love', 'wife', 'california', 'gamer', 'sport']
#
#
# top 50 words in topic 32
# -------------------------
# ['account', 'football', 'central', 'fan', 'talk', 'plant', 'respond', 'onlyfans', 'click', 'life', 'girl', 'bartender', 'author', 'blogger', 'cocktails', 'jazz', 'west', 'new', 'grad', 'post', 'atlanta', 'black', 'raise', 'free', 'things', 'book', 'real', 'dance', 'personal', 'independent', 'old', 'stream', 'wave', 'chargers', 'future', 'partner', 'drink', 'bear', 'tweet', 'south', 'east', 'check', 'punk', 'boston', 'energy', 'night', 'hard', 'dream', 'die', 'music']
#
#
# top 50 words in topic 33
# -------------------------
# ['communications', 'candidate', 'politics', 'information', 'cover', 'florida', 'sport', 'long', 'nfts', 'democrat', 'travel', 'grandmother', 'market', 'president', 'event', 'game', 'husband', 'activist', 'actor', 'proud', 'dad', 'podcast', 'star', 'new', 'check', 'tree', 'things', 'marvel', 'nerd', 'war', 'grad', 'marry', 'advocate', 'generation', 'breed', 'drug', 'bar', 'woman', 'click', 'face', 'team', 'retire', 'board', 'dog', 'security', 'bitch', 'public', 'political', 'mom', 'life']
#
#
# top 50 words in topic 34
# -------------------------
# ['papa', 'make', 'good', 'teach', 'sweet', 'lawyer', 'public', 'hand', 'personal', 'insta', 'endorsement', 'world', 'account', 'league', 'things', 'build', 'label', 'basketball', 'nfl', 'nba', 'model', 'sport', 'fun', 'retire', 'band', 'teacher', 'brother', 'art', 'politics', 'children', 'time', 'like', 'war', 'college', 'opinion', 'available', 'columbia', 'cool', 'best', 'dick', 'ass', 'series', 'business', 'football', 'baseball', 'champion', 'ncaa', 'nigga', 'city', 'study']
#
#
# top 50 words in topic 35
# -------------------------
# ['musician', 'sci', 'wild', 'web', 'assistant', 'tech', 'human', 'instructor', 'family', 'chicago', 'reporter', 'blogger', 'long', 'advocate', 'play', 'veteran', 'fanatic', 'proud', 'software', 'tour', 'videographer', 'watch', 'blue', 'bot', 'rock', 'super', 'guitar', 'christian', 'unite', 'soccer', 'women', 'manager', 'developer', 'website', 'visit', 'transit', 'traffic', 'sport', 'right', 'baseball', 'update', 'player', 'wrestle', 'state', 'songwriter', 'york', 'pro', 'singer', 'new', 'fan']
#
#
# top 50 words in topic 36
# -------------------------
# ['singer', 'business', 'available', 'merch', 'tour', 'rock', 'sci', 'ninja', 'cat', 'creator', 'money', 'daily', 'fighter', 'taste', 'cancer', 'crypto', 'social', 'end', 'american', 'media', 'art', 'native', 'bay', 'history', 'nfts', 'fan', 'snapchat', 'voice', 'music', 'advocate', 'play', 'house', 'chicago', 'horny', 'florida', 'single', 'songwriter', 'culture', 'inquiries', 'artist', 'teach', 'black', 'love', 'person', 'things', 'book', 'new', 'big', 'fun', 'world']
#
#
# top 50 words in topic 37
# -------------------------
# ['favorite', 'happen', 'good', 'san', 'horror', 'bay', 'band', 'photo', 'track', 'movies', 'feature', 'twitter', 'laugh', 'instagram', 'cat', 'night', 'dad', 'retire', 'rip', 'gym', 'rapper', 'lover', 'navy', 'cartoon', 'anime', 'gay', 'break', 'dude', 'big', 'far', 'ass', 'horny', 'like', 'nyc', 'xbox', 'lie', 'brooklyn', 'real', 'dodgers', 'rock', 'win', 'life', 'enthusiast', 'ucla', 'sagittarius', 'lakers', 'fan', 'friends', 'love', 'local']
#
#
# top 50 words in topic 38
# -------------------------
# ['introvert', 'movies', 'spiritual', 'hard', 'breed', 'model', 'happily', 'media', 'post', 'fight', 'backup', 'dancer', 'right', 'pastor', 'alumni', 'husband', 'speaker', 'man', 'hand', 'traveler', 'time', 'cover', 'content', 'lifestyle', 'twitter', 'publisher', 'tire', 'amaze', 'free', 'politics', 'health', 'spirit', 'father', 'advocate', 'christian', 'normal', 'begin', 'addict', 'christ', 'black', 'girl', 'blogger', 'tech', 'news', 'writer', 'vegas', 'bisexual', 'author', 'marry', 'mother']
#
#
# top 50 words in topic 39
# -------------------------
# ['ravenclaw', 'traffic', 'catch', 'dead', 'record', 'red', 'papa', 'unt', 'icon', 'san', 'food', 'make', 'entrepreneur', 'grow', 'unofficial', 'figure', 'service', 'scanner', 'fee', 'employer', 'represent', 'automate', 'nsfw', 'let', 'native', 'connecticut', 'male', 'ambassador', 'man', 'brand', 'collector', 'things', 'nyc', 'oregon', 'actress', 'super', 'business', 'assistant', 'sad', 'post', 'talk', 'blm', 'happy', 'time', 'lose', 'tweet', 'single', 'nurse', 'owner', 'look']
#
#
# top 50 words in topic 40
# -------------------------
# ['wild', 'psn', 'university', 'veteran', 'board', 'post', 'nfts', 'click', 'original', 'good', 'videos', 'animals', 'let', 'tree', 'clean', 'network', 'connect', 'public', 'boy', 'junkie', 'travel', 'podcaster', 'hard', 'unite', 'die', 'avid', 'beach', 'fan', 'history', 'wrestle', 'media', 'cat', 'runner', 'sport', 'meteorologist', 'author', 'nature', 'student', 'walk', 'plant', 'lover', 'relations', 'hoe', 'therapy', 'husband', 'music', 'love', 'dog', 'art', 'dad']
#
#
# top 50 words in topic 41
# -------------------------
# ['illustrator', 'begin', 'quality', 'certify', 'control', 'beauty', 'walk', 'truth', 'disney', 'kid', 'son', 'student', 'change', 'brother', 'public', 'currently', 'radio', 'champion', 'seattle', 'candidate', 'speaker', 'profit', 'proud', 'maker', 'best', 'grow', 'health', 'favorite', 'lover', 'actor', 'martial', 'goofy', 'make', 'chill', 'biology', 'human', 'dog', 'poet', 'designer', 'trans', 'writer', 'better', 'product', 'alumna', 'activist', 'photographer', 'visual', 'blm', 'founder', 'artist']
#
#
# top 50 words in topic 42
# -------------------------
# ['california', 'texas', 'big', 'lookin', 'movie', 'let', 'dicks', 'nigga', 'brooklyn', 'family', 'watch', 'food', 'francisco', 'stand', 'right', 'change', 'wine', 'san', 'photographer', 'design', 'person', 'nfts', 'maker', 'click', 'gamer', 'clean', 'collect', 'blogger', 'visual', 'funny', 'street', 'designer', 'good', 'profit', 'graphic', 'small', 'podcast', 'follow', 'vaxxed', 'stream', 'guy', 'esports', 'poet', 'founder', 'business', 'new', 'owner', 'artist', 'mask', 'nyc']
#
#
# top 50 words in topic 43
# -------------------------
# ['actress', 'backup', 'man', 'old', 'check', 'leo', 'publish', 'author', 'gift', 'animals', 'alumnus', 'anime', 'friend', 'professional', 'chicago', 'game', 'board', 'train', 'aviation', 'big', 'transit', 'urban', 'traveler', 'merch', 'tok', 'bar', 'tik', 'creator', 'god', 'streamer', 'producer', 'music', 'productions', 'youtuber', 'figure', 'young', 'model', 'public', 'disney', 'nerd', 'dream', 'subscribe', 'tweet', 'beautiful', 'live', 'onlyfans', 'founder', 'girl', 'snapchat', 'ceo']
#
#
# top 50 words in topic 44
# -------------------------
# ['bisexual', 'community', 'speaker', 'vegas', 'face', 'drink', 'power', 'work', 'kid', 'mom', 'custom', 'design', 'self', 'knit', 'artist', 'plant', 'paint', 'fitness', 'foodie', 'blogger', 'stay', 'comedy', 'san', 'designer', 'nerd', 'matter', 'metal', 'trainer', 'aficionado', 'red', 'previously', 'mental', 'enjoy', 'support', 'quality', 'project', 'actor', 'home', 'currently', 'beautiful', 'state', 'music', 'writer', 'knight', 'stylist', 'funny', 'life', 'master', 'coach', 'football']
#
#
# top 50 words in topic 45
# -------------------------
# ['seattle', 'sleep', 'short', 'positivity', 'word', 'power', 'education', 'sweet', 'speak', 'kind', 'jesus', 'tech', 'politics', 'city', 'mess', 'follow', 'university', 'proud', 'social', 'man', 'people', 'learn', 'daily', 'want', 'plant', 'life', 'play', 'time', 'box', 'teacher', 'health', 'lot', 'tweet', 'care', 'fanatic', 'enthusiast', 'county', 'class', 'faith', 'pastor', 'coach', 'fan', 'entrepreneur', 'hard', 'graduate', 'music', 'sport', 'school', 'work', 'high']
#
#
# top 50 words in topic 46
# -------------------------
# ['hate', 'christ', 'father', 'seahawks', 'wrestle', 'book', 'comic', 'phil', 'youtube', 'light', 'win', 'stream', 'faith', 'evil', 'band', 'concert', 'practice', 'advice', 'hospital', 'owner', 'conservative', 'retire', 'washington', 'walk', 'happy', 'time', 'happily', 'biden', 'read', 'american', 'fighter', 'tweet', 'recruit', 'young', 'proud', 'live', 'love', 'sport', 'coach', 'freedom', 'president', 'buck', 'mix', 'fight', 'game', 'jesus', 'family', 'video', 'state', 'god']
#
#
# top 50 words in topic 47
# -------------------------
# ['previously', 'shoot', 'mom', 'grammy', 'cancer', 'gamer', 'soccer', 'foodie', 'warzone', 'box', 'research', 'lead', 'network', 'website', 'business', 'ucla', 'advice', 'progressive', 'pro', 'big', 'pop', 'concert', 'philanthropist', 'trader', 'people', 'snap', 'chef', 'nature', 'trade', 'friend', 'sport', 'anti', 'time', 'marry', 'owner', 'commit', 'historian', 'dad', 'coast', 'proud', 'father', 'husband', 'industry', 'kind', 'virgo', 'veteran', 'collector', 'fan', 'best', 'twitter']
#
#
# top 50 words in topic 48
# -------------------------
# ['hospital', 'travel', 'cal', 'widow', 'nyc', 'digital', 'warriors', 'double', 'oakland', 'impact', 'washington', 'pacific', 'create', 'aficionado', 'fanatic', 'county', 'check', 'scene', 'daddy', 'comedian', 'podcast', 'marry', 'sport', 'public', 'streamer', 'latino', 'help', 'texas', 'twitch', 'podcaster', 'wife', 'owner', 'major', 'announcer', 'writer', 'trap', 'art', 'athletics', 'lot', 'earth', 'entertainment', 'affiliate', 'francisco', 'music', 'book', 'play', 'kid', 'state', 'san', 'university']
#
#
# top 50 words in topic 49
# -------------------------
# ['navigate', 'look', 'learn', 'wave', 'central', 'york', 'block', 'nigga', 'big', 'navy', 'lawyer', 'law', 'young', 'black', 'bean', 'actor', 'discord', 'avid', 'voice', 'coffee', 'write', 'lot', 'cat', 'drink', 'grandmother', 'christian', 'teacher', 'owner', 'sunday', 'restaurant', 'school', 'mother', 'art', 'wife', 'play', 'music', 'build', 'information', 'place', 'control', 'alumni', 'seahawks', 'friends', 'instructor', 'fan', 'gang', 'gonna', 'fall', 'freak', 'new']
#
#
# top 50 words in topic 50
# -------------------------
# ['goth', 'real', 'independent', 'power', 'freedom', 'nerd', 'communications', 'advisor', 'exec', 'queen', 'mental', 'travel', 'coffee', 'health', 'aviation', 'chicago', 'book', 'drag', 'bisexual', 'lover', 'comic', 'fan', 'cartoon', 'time', 'things', 'art', 'discord', 'fun', 'texas', 'dallas', 'dog', 'board', 'new', 'pacific', 'laugh', 'michael', 'blm', 'double', 'soul', 'report', 'fanatic', 'gemini', 'monitor', 'performer', 'professional', 'reader', 'old', 'account', 'official', 'writer']
#
#
# top 50 words in topic 51
# -------------------------
# ['historian', 'wine', 'field', 'obsess', 'gal', 'bar', 'fitness', 'train', 'owner', 'assistant', 'midwest', 'coast', 'husband', 'television', 'cute', 'west', 'culture', 'mom', 'lot', 'state', 'fear', 'king', 'basketball', 'new', 'sport', 'coach', 'big', 'guy', 'recruit', 'work', 'public', 'old', 'media', 'aspire', 'philly', 'people', 'mix', 'earth', 'read', 'drink', 'proud', 'god', 'count', 'man', 'pro', 'college', 'movies', 'coordinator', 'peace', 'love']
#
#
# top 50 words in topic 52
# -------------------------
# ['lifestyle', 'boston', 'warriors', 'community', 'digital', 'worker', 'data', 'software', 'nerd', 'employer', 'thinker', 'comic', 'poet', 'aspire', 'audio', 'club', 'past', 'engineer', 'president', 'enthusiast', 'bear', 'learn', 'model', 'journey', 'baseball', 'city', 'home', 'book', 'writer', 'reporter', 'college', 'journalist', 'old', 'fan', 'represent', 'collector', 'sport', 'manager', 'wrestle', 'shark', 'media', 'phd', 'ucla', 'man', 'radio', 'amateur', 'cinematographer', 'livin', 'editor', 'texas']
#
#
# top 50 words in topic 53
# -------------------------
# ['atlanta', 'bad', 'fear', 'adventure', 'tweet', 'new', 'speaker', 'husband', 'fitness', 'father', 'dance', 'historian', 'modern', 'professor', 'district', 'family', 'composer', 'city', 'funny', 'people', 'state', 'focus', 'red', 'liberal', 'exec', 'humanist', 'twitter', 'practice', 'run', 'spirituality', 'teach', 'mom', 'faith', 'school', 'research', 'black', 'producer', 'support', 'winter', 'xxx', 'man', 'owner', 'label', 'oklahoma', 'nerd', 'god', 'guy', 'insta', 'opinions', 'snap']
#
#
# top 50 words in topic 54
# -------------------------
# ['american', 'autistic', 'heart', 'help', 'gay', 'goal', 'traffic', 'fee', 'service', 'women', 'text', 'college', 'basketball', 'post', 'scanner', 'recruit', 'create', 'unofficial', 'automate', 'worker', 'partner', 'performer', 'drag', 'nsfw', 'sex', 'information', 'welcome', 'major', 'pro', 'question', 'respect', 'street', 'bring', 'cook', 'business', 'horror', 'coach', 'trans', 'fan', 'life', 'streamer', 'stop', 'education', 'enjoy', 'arts', 'twitch', 'student', 'live', 'black', 'matter']

# %%
# transform 
df_final = lda.transform(cv_fit)

print('Shape of the df_final:', df_final.shape)
# Out:
# Shape of the df_final: (1644, 55)

# %%
print('\nChecking the probabilitiy distribution of one text data belonging to the topic.\n')
print('Few words from 1st row:', df_new.new_tokens[0][:88],'\n')
print('Probability distribution:', df_final[0])
# Out:
# Checking the probabilitiy distribution of one text data belonging to the topic.
#
# Few words from 1st row: nerdy guy love art music wrestle comics poly
#
# Probability distribution: [0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.36251417 0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.49982349 0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974 ]

# %%
prob = df_final[0][df_final[0].argmax()].round(2)

print('Bio belonging to the topic', df_final[0].argmax(), 'with the probability of', prob)
# Out:
# Bio belonging to the topic 40 with the probability of 0.5

# %%
df_new['cluster'] = df_final.argmax(axis = 1)

df_new.head()
# Out:
#         user_id                                           user_bio  \
# 0  1.180000e+18  I'm a nerdy guy who loves art, music, wrestlin...
# 1  1.440000e+18  No worries Lil Ms Sunshine cause I don't mess ...
# 2  1.219720e+08  I am a huge sports and music fan. I graduated ...
# 3  1.390000e+18  This is not, nor endorsed by, any Government E...
# 4  2.349053e+07  I'm a writer and a cult film fanatic who loves...
#
#                                               tokens state     region  \
# 0       nerdy guy love art music wrestle comics poly    OH    Midwest
# 1  worry lil sunshine cause mess woman moon civil...    PA  Northeast
# 2  huge sport music fan graduate regis university...    CO       West
# 3  endorse government entity project guarantee wa...    WA       West
# 4             writer cult film fanatic love politics    UT       West
#
#                                            ls_tokens  \
# 0  [nerdy, guy, love, art, music, wrestle, comics...
# 1  [worry, sunshine, cause, mess, woman, moon, ci...
# 2  [sport, music, fan, graduate, regis, universit...
# 3  [endorse, government, entity, project, guarant...
# 4      [writer, cult, film, fanatic, love, politics]
#
#                                           new_tokens  cluster
# 0       nerdy guy love art music wrestle comics poly       40
# 1  worry sunshine cause mess woman moon civil rig...       19
# 2  sport music fan graduate regis university live...       45
# 3  endorse government entity project guarantee wa...       44
# 4             writer cult film fanatic love politics        0

# %%
# creating a dictionary with key as topic numbers and value as topic names
#Joscelin used random genres here to see if everything is working

topic_label = {0:'punkrock', 1:'chill', 2:'punk', 3:'latino', 4:'happy', 5:'rock',6:'rnb', 7:'edm',8:'goth',9:'happy', 10:'gospel', 11:'house', 12:'edm', 13:'songwriter', 
14:'latino', 15:'comedy', 16:'anime', 17:'jrock', 18:'country', 19:'edm', 20:'disco', 21:'gospel', 22:'ambient', 23:'gospel', 24:'jazz', 25:'pop', 26:'honkytonk',
27:'newage', 28:'latino', 29:'heavymetal', 30:'pop', 31:'romance', 32:'acoustic', 33:'newage', 34:'afrobeat', 35:'party', 36:'rockabilly', 37:'punkrock', 38:'jazz', 
39:'altrock', 40:'soul', 41:'funk', 42:'newage', 43:'groove', 44:'minimaltechno', 45:'acoustic', 46:'dancehall', 47:'heavymetal', 48:'club', 49:'breakbeat', 50:'punkrock',
51:'country', 52:'reggae', 53:'anime', 54:'rockabilly'}

# mapping the dictionary with the dataframe to get the labels.
df_new['genre'] = df_new['cluster'].map(topic_label)

#saving new dataframe
#df_new.to_csv(r'data/twitter_genre_after_LDA.csv', index = False,   
#                 header=True)
# head of the dataframe
df_new.head()
# Out:
#         user_id                                           user_bio  \
# 0  1.180000e+18  I'm a nerdy guy who loves art, music, wrestlin...
# 1  1.440000e+18  No worries Lil Ms Sunshine cause I don't mess ...
# 2  1.219720e+08  I am a huge sports and music fan. I graduated ...
# 3  1.390000e+18  This is not, nor endorsed by, any Government E...
# 4  2.349053e+07  I'm a writer and a cult film fanatic who loves...
#
#                                               tokens state     region  \
# 0       nerdy guy love art music wrestle comics poly    OH    Midwest
# 1  worry lil sunshine cause mess woman moon civil...    PA  Northeast
# 2  huge sport music fan graduate regis university...    CO       West
# 3  endorse government entity project guarantee wa...    WA       West
# 4             writer cult film fanatic love politics    UT       West
#
#                                            ls_tokens  \
# 0  [nerdy, guy, love, art, music, wrestle, comics...
# 1  [worry, sunshine, cause, mess, woman, moon, ci...
# 2  [sport, music, fan, graduate, regis, universit...
# 3  [endorse, government, entity, project, guarant...
# 4      [writer, cult, film, fanatic, love, politics]
#
#                                           new_tokens  cluster          genre
# 0       nerdy guy love art music wrestle comics poly       40           soul
# 1  worry sunshine cause mess woman moon civil rig...       19            edm
# 2  sport music fan graduate regis university live...       45       acoustic
# 3  endorse government entity project guarantee wa...       44  minimaltechno
# 4             writer cult film fanatic love politics        0       punkrock

# %% [markdown]
# ## Visualization: Wordclouds

# %% [markdown]
# #### All Bios

# %%
#Frequency of words
from wordcloud import WordCloud
from nltk import FreqDist
import matplotlib.pyplot as plt


string = pd.Series(df_new['new_tokens']).str.cat(sep = ' ')


#WordCloud
wordcloud = WordCloud(width = 3800,height = 3100,max_words = 500,max_font_size = 1200,collocations = False, background_color='black').generate(string)
plt.figure(figsize = (400,300))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")
plt.savefig('figs/all_bios.png',bbox_inches = 'tight')

# %%
genres_names = ['punkrock','chill','punk','latino','happy','rock','rnb', 'edm','goth','house', 'songwriter','comedy', 
                'anime', 'jrock', 'disco', 'gospel', 'ambient','jazz', 'pop', 'honkytonk','newage', 'heavymetal', 
                'romance','acoustic','afrobeat', 'party', 'rockabilly', 'altrock', 'soul', 'funk', 'groove', 
                'minimaltechno', 'dancehall', 'club','breakbeat','country', 'reggae']
    
count = 0 # in case items is empty
#for count, item in enumerate(genres_names, start = 1):
#    filtered_df = df_new[df_new['genre'] == item]
#    print('{}. Plot for genre: {}'.format(count,item))
#    pngs = 'figs/{}_plot_{}.png'.format(count,item)
#    string = pd.Series(filtered_df['new_tokens']).str.cat(sep = ' ')
#    #WordCloud
#    wordcloud = WordCloud(width = 3800,height = 3100,max_words = 500,max_font_size = 1200,collocations = False, background_color = 'black').generate(string)
#    plt.figure(figsize = (400,300))
#    plt.imshow(wordcloud, interpolation = "bilinear")
#    plt.axis("off")
#    plt.savefig(pngs,bbox_inches = 'tight')
#    print ("Done! You can see it in the folder now.")
