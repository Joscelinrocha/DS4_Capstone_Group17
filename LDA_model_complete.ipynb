# %%
## Joscelin is following these steps: https://github.com/Sandeep-Panchal/Topic-Modeling-with-LDA/blob/master/Topic-Modeling-IPYNB/Topic%20Modeling%20with%20LDA.ipynb

import numpy as np
import pandas as pd
import random

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/twitter_data_clean_final.csv')
df = df.loc[:,["user_id","user_bio","tokens","state","region"]]
df.dropna(inplace=True)
df
# deep copy to avoid override of the original dataframe
import copy

df_new = copy.deepcopy(df)

to_remove = ['act', 'car', 'card', 'acct','acab','ada','admin','aew','age', 'ain', 'aka','alt','alum', 'angeleno', 'answer','antonio','app',
            'area','ask','atl', 'ben', 'brady','brandon', 'chair','circle','clue','collab','com', 'come', 'day', 'dedicate',
            'dev', 'dms', 'dont', 'dot', 'drive', 'driver', 'eat', 'email', 'eth', 'feed', 'form', 'fsu', 'gas', 'giants',
            'google', 'group', 'hair', 'half','harris', 'head','hear','hip', 'hire','hit','hiv','holder','host', 'hold',
            'huge', 'ill', 'info', 'inquire','inquires', 'internet', 'investor', 'investors', 'jeff', 'jack', 'job', 'joe',
            'john', 'join', 'know', 'las', 'lake', ' let', 'lil', 'line', 'link','listen', 'little', 'llc', 'los', 'main', 
            'meet', 'member', 'miles', 'mma', 'multi','near', 'need', 'nice', 'nominate', 'non', 'nut', 'okay', 'open', 
            'order', 'padres', 'page', 'park', 'pin', 'plug', 'print','provide', 'providence', 'ram', 'sag', 'say', 'sell', 'set', 
            'stl','sth','sub', 'syndication', 'tell', 'tony', 'true', 'try', 'tryna', 'type', 'typos', 'usa', 'use', 'valley', 
            'verse', 'view', 'way', 'year', 'years', 'yrs']


            
def stringToList(string):
    listRes = list(string.split(" "))
    return listRes

ls_tokens = []  

for cell in df_new.tokens: 
    cell = stringToList(cell)
    ls_tokens.append(cell)
    


for cell in ls_tokens: 
    for word in list(cell):
        if word in to_remove:
            cell.remove(word)
            
df_new['ls_tokens'] = ls_tokens

df_new['new_tokens'] = [' '.join(map(str, l)) for l in df_new['ls_tokens']]
df_new
# Out:
#            user_id                                           user_bio  \
# 0     1.180000e+18  I'm a nerdy guy who loves art, music, wrestlin...
# 1     1.440000e+18  No worries Lil Ms Sunshine cause I don't mess ...
# 2     1.219720e+08  I am a huge sports and music fan. I graduated ...
# 3     1.390000e+18  This is not, nor endorsed by, any Government E...
# 4     2.349053e+07  I'm a writer and a cult film fanatic who loves...
# ...            ...                                                ...
# 1723  2.961228e+08  Christian. Husband. Father. Ph.D. Candidate @B...
# 1724  8.800000e+17  MarTech, MBA, Foodie, Bilingual, Soccer, Boxin...
# 1725  1.153059e+09  streams occasionally, will choose race cars ov...
# 1726  2.432869e+08  Enjoy the practical wisdom of daily life. Prom...
# 1727  2.159799e+09                                    glass half full
#
#                                                  tokens state     region  \
# 0          nerdy guy love art music wrestle comics poly    OH    Midwest
# 1     worry lil sunshine cause mess woman moon civil...    PA  Northeast
# 2     huge sport music fan graduate regis university...    CO       West
# 3     endorse government entity project guarantee wa...    WA       West
# 4                writer cult film fanatic love politics    UT       West
# ...                                                 ...   ...        ...
# 1723  christian husband father candidate mosquito re...    OH    Midwest
# 1724  martech mba foodie bilingual soccer box gamer ...    CA       West
# 1725  stream occasionally choose race cars important...    KY      South
# 1726  enjoy practical wisdom daily life promote trut...    AZ  Southwest
# 1727                                         glass half    MO    Midwest
#
#                                               ls_tokens  \
# 0     [nerdy, guy, love, art, music, wrestle, comics...
# 1     [worry, sunshine, cause, mess, woman, moon, ci...
# 2     [sport, music, fan, graduate, regis, universit...
# 3     [endorse, government, entity, project, guarant...
# 4         [writer, cult, film, fanatic, love, politics]
# ...                                                 ...
# 1723  [christian, husband, father, candidate, mosqui...
# 1724  [martech, mba, foodie, bilingual, soccer, box,...
# 1725  [stream, occasionally, choose, race, cars, imp...
# 1726  [enjoy, practical, wisdom, daily, life, promot...
# 1727                                            [glass]
#
#                                              new_tokens
# 0          nerdy guy love art music wrestle comics poly
# 1     worry sunshine cause mess woman moon civil rig...
# 2     sport music fan graduate regis university live...
# 3     endorse government entity project guarantee wa...
# 4                writer cult film fanatic love politics
# ...                                                 ...
# 1723  christian husband father candidate mosquito re...
# 1724  martech mba foodie bilingual soccer box gamer ...
# 1725  stream occasionally choose race cars important...
# 1726  enjoy practical wisdom daily life promote trut...
# 1727                                              glass
#
# [1644 rows x 7 columns]

# %%
# importing TFIDF vectorizer
from sklearn.feature_extraction.text import CountVectorizer

# creating an instance
cv = CountVectorizer(max_df = 0.90, min_df = 3, stop_words = 'english')

# fit and transform the text data
cv_fit = cv.fit_transform(df_new.new_tokens)

print('\nShape of the sparse matrix\n')
cv_fit
# Out:
# Shape of the sparse matrix
# <1644x825 sparse matrix of type '<class 'numpy.int64'>'
# 	with 6348 stored elements in Compressed Sparse Row format>

# %%
# importing Latent Dirichlet Allocation library
from sklearn.decomposition import LatentDirichletAllocation

# creating an instance for LDA
lda = LatentDirichletAllocation(n_components = 55, random_state = 3)

# %%
# %%time

print('Fitting the vectorizer with the LDA')

lda.fit(cv_fit)
# Out:
# Fitting the vectorizer with the LDA
# CPU times: total: 1.31 s
# Wall time: 1.31 s
# LatentDirichletAllocation(n_components=55, random_state=3)

# %%
print('Number of topic:', len(lda.components_))
print('Number of column of the lda fit:',len(lda.components_[0]))
cv
# Out:
# Number of topic: 55
# Number of column of the lda fit: 825
# CountVectorizer(max_df=0.9, min_df=3, stop_words='english')

# %%
feature = cv.get_feature_names()

print('Length of feature names:', len(feature))
# Out:
# Length of feature names: 825

# %%
for ind, topic in enumerate(lda.components_):
    print('top 50 words in topic {}'.format(ind))
    print('-'*25)
    top_50 = topic.argsort()[-50:]
    print([feature[i] for i in top_50], '\n\n')
# Out:
# top 50 words in topic 0
# -------------------------
# ['filmmaker', 'financial', 'fitness', 'dream', 'florida', 'post', 'shit', 'bisexual', 'dancer', 'model', 'arts', 'student', 'right', 'professionals', 'grow', 'best', 'help', 'estate', 'property', 'control', 'base', 'band', 'want', 'food', 'clean', 'water', 'live', 'air', 'backup', 'real', 'fan', 'business', 'free', 'product', 'reader', 'ninja', 'pay', 'train', 'quality', 'punk', 'certify', 'energy', 'chicago', 'healthcare', 'life', 'account', 'house', 'entertainment', 'official', 'twitter']
#
#
# top 50 words in topic 1
# -------------------------
# ['ones', 'mess', 'women', 'run', 'normal', 'human', 'picture', 'bot', 'block', 'bean', 'sport', 'runner', 'meteorologist', 'deep', 'market', 'baby', 'media', 'beer', 'communications', 'work', 'bring', 'play', 'world', 'bear', 'healthcare', 'talent', 'service', 'raise', 'estate', 'value', 'florida', 'seattle', 'truth', 'forever', 'comedian', 'dad', 'regular', 'real', 'sagittarius', 'social', 'let', 'live', 'love', 'like', 'texas', 'build', 'experience', 'heart', 'bless', 'boy']
#
#
# top 50 words in topic 2
# -------------------------
# ['buff', 'events', 'club', 'podcast', 'tour', 'write', 'build', 'lot', 'drink', 'play', 'coffee', 'nerd', 'vegan', 'money', 'fight', 'sci', 'creator', 'ninja', 'film', 'husband', 'media', 'include', 'photography', 'make', 'dodgers', 'anime', 'navy', 'lakers', 'friends', 'fan', 'cartoon', 'world', 'gonna', 'talent', 'vet', 'musician', 'digital', 'stream', 'lover', 'history', 'cat', 'man', 'ucla', 'raise', 'angeles', 'artist', 'family', 'fun', 'love', 'god']
#
#
# top 50 words in topic 3
# -------------------------
# ['speak', 'face', 'youtube', 'band', 'cover', 'columbia', 'rock', 'fitness', 'employer', 'trap', 'plant', 'stan', 'beach', 'quality', 'variety', 'life', 'previously', 'lose', 'mixer', 'sex', 'performer', 'partner', 'nsfw', 'worker', 'drag', 'like', 'black', 'music', 'love', 'matter', 'funny', 'live', 'talk', 'street', 'respect', 'subscribe', 'fun', 'streamer', 'let', 'news', 'assistant', 'nurse', 'bitch', 'trans', 'knight', 'onlyfans', 'bartender', 'bio', 'twitch', 'affiliate']
#
#
# top 50 words in topic 4
# -------------------------
# ['baseball', 'play', 'modern', 'mean', 'win', 'forget', 'rule', 'army', 'ambassador', 'father', 'fan', 'disable', 'brand', 'veteran', 'marry', 'photography', 'education', 'proud', 'writer', 'digital', 'kind', 'activist', 'power', 'speak', 'sweet', 'mind', 'coach', 'trade', 'blogger', 'check', 'thinker', 'care', 'life', 'university', 'roll', 'far', 'spiritual', 'free', 'guitar', 'leave', 'lead', 'tweet', 'dice', 'word', 'code', 'player', 'music', 'model', 'tiktok', 'video']
#
#
# top 50 words in topic 5
# -------------------------
# ['affiliate', 'nft', 'producer', 'exec', 'podcaster', 'cancer', 'practice', 'focus', 'oklahoma', 'senior', 'advisor', 'trojan', 'progressive', 'democrat', 'usc', 'ball', 'certify', 'build', 'run', 'brother', 'burn', 'study', 'hot', 'girl', 'random', 'long', 'fast', 'cool', 'mind', 'texas', 'respect', 'independent', 'fan', 'love', 'art', 'artist', 'cowboys', 'guess', 'history', 'people', 'high', 'chef', 'stay', 'cub', 'probably', 'stage', 'thinker', 'inspire', 'like', 'class']
#
#
# top 50 words in topic 6
# -------------------------
# ['rock', 'favorite', 'hate', 'movies', 'band', 'horror', 'awesome', 'unt', 'nsfw', 'stand', 'help', 'talent', 'special', 'army', 'comedian', 'hour', 'shoot', 'comedy', 'ceo', 'athlete', 'amaze', 'veteran', 'coach', 'author', 'children', 'war', 'politics', 'film', 'photographer', 'gang', 'paint', 'design', 'peace', 'rest', 'nature', 'nfts', 'follow', 'real', 'life', 'business', 'major', 'snap', 'fan', 'love', 'therapy', 'account', 'study', 'enjoy', 'art', 'photography']
#
#
# top 50 words in topic 7
# -------------------------
# ['season', 'strong', 'health', 'counselor', 'spirit', 'knit', 'specialist', 'research', 'employer', 'community', 'development', 'support', 'meteorologist', 'aviation', 'past', 'geek', 'fan', 'veteran', 'sales', 'politics', 'business', 'senior', 'air', 'technology', 'navy', 'love', 'cancer', 'tech', 'singer', 'liberal', 'traveler', 'sense', 'retire', 'trader', 'writer', 'kentucky', 'youtube', 'manager', 'sport', 'teacher', 'soft', 'seattle', 'lover', 'consultant', 'educator', 'touch', 'alumnus', 'social', 'media', 'opinions']
#
#
# top 50 words in topic 8
# -------------------------
# ['endorsement', 'control', 'navigate', 'smart', 'history', 'politics', 'usc', 'fitness', 'class', 'tech', 'stage', 'husband', 'person', 'joke', 'speaker', 'animals', 'blue', 'vote', 'wine', 'journey', 'addict', 'currently', 'code', 'student', 'taste', 'traveler', 'dallas', 'promoter', 'wrestle', 'guitar', 'book', 'sport', 'movies', 'dog', 'owner', 'food', 'tree', 'play', 'wave', 'old', 'lose', 'earth', 'save', 'gun', 'opinions', 'like', 'learn', 'father', 'california', 'nerd']
#
#
# top 50 words in topic 9
# -------------------------
# ['resident', 'wife', 'college', 'chicago', 'kid', 'recruit', 'basketball', 'funny', 'actor', 'women', 'information', 'beautiful', 'marry', 'healthcare', 'voice', 'blogger', 'help', 'master', 'home', 'big', 'far', 'dude', 'break', 'win', 'lie', 'like', 'ass', 'gay', 'horny', 'owner', 'check', 'new', 'sleep', 'text', 'want', 'sponsor', 'die', 'power', 'fee', 'productions', 'super', 'coach', 'question', 'life', 'project', 'work', 'good', 'mom', 'long', 'time']
#
#
# top 50 words in topic 10
# -------------------------
# ['educator', 'feature', 'book', 'original', 'boy', 'bio', 'events', 'expert', 'fav', 'tik', 'people', 'family', 'tok', 'nerd', 'collector', 'connecticut', 'shit', 'forever', 'lover', 'single', 'editor', 'liberal', 'male', 'talk', 'lose', 'vote', 'videos', 'nft', 'author', 'mom', 'teacher', 'creator', 'insta', 'love', 'artist', 'video', 'publish', 'base', 'game', 'man', 'singer', 'cool', 'like', 'taste', 'let', 'shoot', 'alumna', 'livin', 'visual', 'photographer']
#
#
# top 50 words in topic 11
# -------------------------
# ['web', 'click', 'actress', 'data', 'commit', 'school', 'county', 'ncaa', 'high', 'alumnus', 'politics', 'kings', 'candidate', 'chargers', 'cover', 'sport', 'welcome', 'bring', 'fan', 'help', 'series', 'world', 'comedian', 'activist', 'actor', 'rapper', 'artist', 'writer', 'athlete', 'martial', 'organizer', 'real', 'girl', 'pacific', 'goal', 'coast', 'lakers', 'dodgers', 'model', 'bedroom', 'league', 'tweet', 'time', 'horror', 'baseball', 'random', 'metal', 'baby', 'champion', 'proud']
#
#
# top 50 words in topic 12
# -------------------------
# ['pay', 'hop', 'arsenal', 'introvert', 'pretty', 'joke', 'ambassador', 'single', 'advisor', 'financial', 'american', 'voice', 'mom', 'black', 'washington', 'enjoy', 'transplant', 'new', 'person', 'click', 'blogger', 'gamer', 'follow', 'poet', 'self', 'law', 'smile', 'mean', 'sex', 'creative', 'grad', 'creator', 'blue', 'currently', 'funny', 'work', 'school', 'beautiful', 'break', 'artist', 'fan', 'mind', 'native', 'nyc', 'life', 'sun', 'nsfw', 'girl', 'university', 'state']
#
#
# top 50 words in topic 13
# -------------------------
# ['catch', 'runner', 'army', 'truck', 'meteorologist', 'market', 'club', 'icon', 'text', 'enjoy', 'everyday', 'help', 'dancer', 'pop', 'collector', 'friend', 'best', 'fan', 'influencer', 'miss', 'merch', 'tik', 'tok', 'creator', 'comedian', 'podcaster', 'trap', 'county', 'daddy', 'podcast', 'artist', 'work', 'writer', 'illustrator', 'scene', 'chef', 'nurse', 'fast', 'think', 'tweet', 'marry', 'book', 'disney', 'bar', 'let', 'professional', 'check', 'dream', 'american', 'designer']
#
#
# top 50 words in topic 14
# -------------------------
# ['digital', 'world', 'company', 'build', 'author', 'bartender', 'cocktails', 'blogger', 'boy', 'president', 'person', 'avid', 'regular', 'american', 'hard', 'runner', 'unite', 'junkie', 'die', 'school', 'love', 'taste', 'fighter', 'daily', 'voice', 'cancer', 'new', 'owner', 'man', 'broncos', 'movies', 'game', 'politics', 'beach', 'team', 'book', 'help', 'media', 'teach', 'things', 'art', 'drink', 'fan', 'follow', 'podcaster', 'run', 'money', 'food', 'travel', 'boston']
#
#
# top 50 words in topic 15
# -------------------------
# ['people', 'feature', 'bay', 'oakland', 'student', 'athletics', 'east', 'god', 'sing', 'lol', 'happen', 'modern', 'owner', 'historian', 'professor', 'dance', 'lead', 'research', 'website', 'life', 'amaze', 'lifestyle', 'advocate', 'care', 'clean', 'dad', 'foodie', 'nature', 'blogger', 'tree', 'account', 'houston', 'season', 'worker', 'real', 'estate', 'district', 'relations', 'network', 'animals', 'walk', 'home', 'industry', 'specialist', 'social', 'state', 'plant', 'connect', 'love', 'texas']
#
#
# top 50 words in topic 16
# -------------------------
# ['father', 'founder', 'friend', 'freedom', 'fox', 'family', 'fast', 'free', 'fashion', 'francisco', 'far', 'fav', 'fanatic', 'twitter', 'cover', 'judge', 'film', 'horror', 'obsess', 'wild', 'tongue', 'author', 'raw', 'executive', 'leader', 'director', 'industry', 'independent', 'professionals', 'specialize', 'home', 'company', 'work', 'comic', 'faith', 'fan', 'book', 'pastor', 'songwriter', 'editor', 'hunter', 'singer', 'develop', 'contact', 'unmonitored', 'national', 'service', 'office', 'weather', 'follow']
#
#
# top 50 words in topic 17
# -------------------------
# ['kid', 'chief', 'cat', 'designer', 'scientist', 'like', 'creativity', 'crypto', 'bitch', 'dick', 'sci', 'writer', 'organizer', 'pop', 'educator', 'culture', 'biden', 'president', 'walk', 'state', 'retire', 'washington', 'school', 'grandmother', 'owner', 'teacher', 'wife', 'restaurant', 'sunday', 'christian', 'art', 'big', 'win', 'pussy', 'want', 'nft', 'marry', 'collector', 'happily', 'happy', 'dog', 'instructor', 'artist', 'read', 'universe', 'arts', 'friend', 'time', 'love', 'mother']
#
#
# top 50 words in topic 18
# -------------------------
# ['west', 'american', 'disable', 'thoughts', 'unite', 'director', 'development', 'retire', 'autistic', 'announcer', 'inquiries', 'kid', 'track', 'earth', 'major', 'man', 'weather', 'entertainment', 'help', 'metaverse', 'law', 'read', 'god', 'beauty', 'travel', 'introvert', 'opinions', 'laugh', 'sound', 'feature', 'movies', 'artist', 'nyc', 'irl', 'account', 'bring', 'fashion', 'good', 'founder', 'old', 'book', 'love', 'writer', 'death', 'nft', 'music', 'actor', 'marry', 'shit', 'write']
#
#
# top 50 words in topic 19
# -------------------------
# ['history', 'addict', 'chocolate', 'people', 'board', 'communications', 'cover', 'college', 'information', 'past', 'proud', 'big', 'philanthropist', 'ucla', 'beautiful', 'kid', 'world', 'marry', 'actress', 'animal', 'friend', 'travel', 'graduate', 'children', 'pan', 'irl', 'word', 'mean', 'currently', 'dad', 'lover', 'specialize', 'papa', 'update', 'win', 'producer', 'stream', 'box', 'oregon', 'yoga', 'high', 'progressive', 'school', 'sport', 'love', 'create', 'fan', 'public', 'play', 'things']
#
#
# top 50 words in topic 20
# -------------------------
# ['cashapp', 'heart', 'support', 'old', 'proud', 'researcher', 'phd', 'sport', 'mission', 'arsenal', 'buff', 'easy', 'movie', 'health', 'mental', 'advocate', 'impact', 'chicago', 'creative', 'grad', 'leader', 'philanthropist', 'knight', 'chief', 'podcaster', 'columbia', 'usc', 'designer', 'player', 'things', 'write', 'creator', 'trans', 'poly', 'pan', 'obsess', 'conservative', 'mean', 'medical', 'success', 'self', 'man', 'lover', 'food', 'dead', 'single', 'blm', 'let', 'friends', 'look']
#
#
# top 50 words in topic 21
# -------------------------
# ['lead', 'wife', 'brother', 'talk', 'nigga', 'gang', 'dead', 'big', 'graphic', 'designer', 'cult', 'politics', 'fanatic', 'film', 'dog', 'work', 'roll', 'rule', 'earth', 'custom', 'private', 'rock', 'forget', 'follow', 'tip', 'help', 'news', 'latest', 'wanna', 'burn', 'insta', 'stop', 'man', 'writer', 'leave', 'girl', 'sign', 'read', 'freak', 'die', 'love', 'account', 'great', 'kid', 'want', 'young', 'new', 'book', 'favorite', 'old']
#
#
# top 50 words in topic 22
# -------------------------
# ['light', 'major', 'real', 'culture', 'city', 'proud', 'professional', 'hop', 'enthusiast', 'lover', 'painter', 'illustrator', 'quality', 'clean', 'create', 'focus', 'community', 'raise', 'president', 'time', 'play', 'soccer', 'matter', 'songwriter', 'fan', 'singer', 'sci', 'sport', 'musician', 'traveler', 'nerd', 'new', 'ceo', 'photographer', 'happen', 'oklahoma', 'man', 'independent', 'michael', 'enjoy', 'bring', 'bear', 'biology', 'millionaire', 'coach', 'cal', 'future', 'fighter', 'life', 'pro']
#
#
# top 50 words in topic 23
# -------------------------
# ['lawyer', 'political', 'events', 'lgbtq', 'philanthropist', 'podcast', 'avid', 'travel', 'voice', 'black', 'professional', 'actor', 'mental', 'coffee', 'aviation', 'bean', 'discord', 'jazz', 'world', 'pop', 'politics', 'husband', 'aspire', 'television', 'coast', 'cute', 'west', 'work', 'stuff', 'fanatic', 'art', 'check', 'gym', 'party', 'life', 'public', 'advocate', 'super', 'bring', 'science', 'music', 'midwest', 'future', 'embrace', 'health', 'movies', 'creative', 'fan', 'love', 'director']
#
#
# top 50 words in topic 24
# -------------------------
# ['libra', 'deep', 'run', 'teacher', 'worker', 'license', 'humanist', 'democrat', 'cult', 'positivity', 'clean', 'happily', 'real', 'respond', 'energy', 'onlyfans', 'girl', 'kid', 'club', 'coach', 'hop', 'best', 'family', 'town', 'friends', 'home', 'learn', 'beer', 'travel', 'software', 'social', 'talk', 'aficionado', 'fan', 'click', 'life', 'dream', 'composer', 'engineer', 'designer', 'arts', 'man', 'liberal', 'volunteer', 'watch', 'base', 'night', 'love', 'producer', 'music']
#
#
# top 50 words in topic 25
# -------------------------
# ['cover', 'cars', 'film', 'check', 'philosophy', 'outdoors', 'fan', 'personality', 'feature', 'cat', 'passion', 'big', 'retire', 'lakers', 'rapper', 'heart', 'laugh', 'crypto', 'enthusiast', 'positivity', 'daily', 'fanatic', 'financial', 'lord', 'kid', 'make', 'opportunities', 'dad', 'want', 'wife', 'goofy', 'rest', 'short', 'seattle', 'health', 'entrepreneur', 'sport', 'youtube', 'lion', 'adventure', 'christ', 'proud', 'live', 'rip', 'jesus', 'like', 'radio', 'best', 'love', 'life']
#
#
# top 50 words in topic 26
# -------------------------
# ['tok', 'bio', 'tik', 'man', 'kind', 'best', 'animals', 'travel', 'game', 'opinions', 'advice', 'advocate', 'dancer', 'tattoo', 'cashapp', 'friend', 'care', 'big', 'break', 'videos', 'metaverse', 'impact', 'ceo', 'agency', 'figure', 'media', 'artist', 'twitter', 'want', 'male', 'visual', 'student', 'play', 'american', 'maker', 'poly', 'mom', 'news', 'nft', 'music', 'book', 'entrepreneur', 'fall', 'influencer', 'inquiries', 'trump', 'grad', 'crypto', 'market', 'business']
#
#
# top 50 words in topic 27
# -------------------------
# ['variety', 'alumnus', 'change', 'american', 'awesome', 'leave', 'play', 'build', 'star', 'reality', 'feel', 'social', 'gaymer', 'pay', 'family', 'daily', 'nerd', 'spirituality', 'research', 'mom', 'run', 'faith', 'school', 'health', 'information', 'website', 'visit', 'opportunities', 'latest', 'dog', 'life', 'horny', 'unt', 'videographer', 'sad', 'drug', 'thoughts', 'think', 'want', 'talk', 'retire', 'streamer', 'twitch', 'business', 'learn', 'ball', 'love', 'teach', 'senior', 'live']
#
#
# top 50 words in topic 28
# -------------------------
# ['post', 'free', 'wave', 'georgia', 'leo', 'daily', 'life', 'speaker', 'drink', 'beautiful', 'matter', 'vegas', 'raise', 'bartender', 'bear', 'model', 'big', 'girl', 'real', 'agent', 'team', 'service', 'musician', 'estate', 'award', 'win', 'anchor', 'guy', 'lover', 'city', 'instructor', 'chicago', 'proud', 'blogger', 'family', 'human', 'media', 'reporter', 'ambassador', 'license', 'humanity', 'writer', 'actress', 'face', 'blue', 'play', 'sport', 'women', 'cinematographer', 'right']
#
#
# top 50 words in topic 29
# -------------------------
# ['mask', 'philosophy', 'hop', 'change', 'junkie', 'recruit', 'reporter', 'daily', 'sunday', 'past', 'power', 'team', 'high', 'nurse', 'people', 'organizer', 'engineer', 'today', 'teacher', 'lead', 'fan', 'ravenclaw', 'affiliate', 'san', 'snapchat', 'father', 'mom', 'women', 'central', 'activist', 'esports', 'sign', 'coach', 'right', 'east', 'husband', 'dad', 'middle', 'marvel', 'twitch', 'music', 'retire', 'proud', 'wanna', 'south', 'nerd', 'sport', 'school', 'war', 'star']
#
#
# top 50 words in topic 30
# -------------------------
# ['endorsement', 'generation', 'positivity', 'aspire', 'speak', 'brother', 'middle', 'pastor', 'christ', 'speaker', 'raw', 'pizza', 'wrestle', 'pro', 'hand', 'normal', 'blogger', 'conservative', 'daddy', 'student', 'traveler', 'time', 'father', 'adventure', 'begin', 'mental', 'man', 'great', 'son', 'light', 'nyc', 'league', 'trump', 'bear', 'peace', 'real', 'winter', 'stick', 'graduate', 'breed', 'author', 'crazy', 'raise', 'baseball', 'fan', 'long', 'bitch', 'matter', 'black', 'live']
#
#
# top 50 words in topic 31
# -------------------------
# ['old', 'southern', 'scorpio', 'soul', 'trump', 'biden', 'face', 'queen', 'advisor', 'exec', 'board', 'communications', 'learn', 'teach', 'beauty', 'heart', 'truth', 'activist', 'walk', 'lead', 'kid', 'disney', 'trans', 'blm', 'stuff', 'include', 'follow', 'write', 'podcast', 'coach', 'resident', 'things', 'bring', 'vaxxed', 'actor', 'dog', 'lover', 'teacher', 'poet', 'son', 'voice', 'blood', 'writer', 'team', 'mask', 'feel', 'place', 'welcome', 'world', 'new']
#
#
# top 50 words in topic 32
# -------------------------
# ['guitar', 'politics', 'partner', 'cartoon', 'strong', 'mother', 'author', 'stay', 'run', 'outdoors', 'new', 'league', 'feature', 'war', 'enjoy', 'currently', 'experience', 'talk', 'create', 'storyteller', 'comic', 'coffee', 'thinker', 'single', 'dad', 'grad', 'buff', 'collector', 'poet', 'history', 'connect', 'merch', 'relations', 'concert', 'best', 'story', 'fan', 'love', 'artist', 'music', 'star', 'production', 'aspire', 'basketball', 'writer', 'kind', 'wrestle', 'vegas', 'local', 'manager']
#
#
# top 50 words in topic 33
# -------------------------
# ['soul', 'goth', 'red', 'icon', 'record', 'warriors', 'san', 'fanatic', 'state', 'oakland', 'francisco', 'athletics', 'fun', 'wanna', 'play', 'food', 'stand', 'drag', 'programmer', 'bartender', 'enthusiast', 'thoughts', 'bear', 'gun', 'end', 'raise', 'violence', 'chicago', 'alumni', 'passion', 'politics', 'photography', 'design', 'punk', 'traffic', 'stop', 'grand', 'stream', 'create', 'creative', 'organizer', 'fee', 'automate', 'scanner', 'unofficial', 'service', 'post', 'professional', 'snap', 'like']
#
#
# top 50 words in topic 34
# -------------------------
# ['hand', 'counselor', 'biden', 'fear', 'hard', 'bisexual', 'love', 'girl', 'breed', 'alumnus', 'research', 'christian', 'candidate', 'creativity', 'actor', 'young', 'youtube', 'comic', 'coach', 'game', 'wrestle', 'video', 'wife', 'storyteller', 'dog', 'winner', 'anchor', 'mom', 'writer', 'model', 'like', 'author', 'fox', 'florida', 'special', 'buck', 'blm', 'better', 'warriors', 'husband', 'father', 'book', 'emmy', 'custom', 'videos', 'gift', 'buy', 'soul', 'news', 'god']
#
#
# top 50 words in topic 35
# -------------------------
# ['philly', 'vet', 'bear', 'blm', 'bad', 'humanist', 'liberal', 'enjoy', 'buck', 'football', 'talk', 'chargers', 'die', 'hard', 'watch', 'native', 'account', 'field', 'metal', 'wine', 'bar', 'pro', 'war', 'drink', 'spur', 'cowboys', 'punk', 'young', 'martial', 'mix', 'family', 'passion', 'friends', 'arts', 'cute', 'lol', 'shop', 'veteran', 'wake', 'obsess', 'gal', 'state', 'love', 'cook', 'sport', 'nba', 'follow', 'life', 'collector', 'fan']
#
#
# top 50 words in topic 36
# -------------------------
# ['fear', 'feature', 'fee', 'feel', 'field', 'fight', 'fast', 'illustrator', 'owner', 'account', 'business', 'star', 'designer', 'composer', 'sales', 'company', 'cinema', 'grad', 'news', 'advice', 'veteran', 'trade', 'east', 'painter', 'lord', 'obsess', 'tweeter', 'beauty', 'grow', 'high', 'trainer', 'south', 'personal', 'beautiful', 'children', 'marry', 'work', 'good', 'writer', 'trader', 'philosophy', 'father', 'stylist', 'coach', 'life', 'city', 'person', 'football', 'love', 'instagram']
#
#
# top 50 words in topic 37
# -------------------------
# ['owner', 'college', 'basketball', 'history', 'tech', 'fitness', 'teacher', 'original', 'vet', 'wrestle', 'life', 'proud', 'social', 'mom', 'student', 'alumni', 'friend', 'lover', 'blogger', 'actor', 'post', 'psn', 'urban', 'animals', 'politics', 'leo', 'attorney', 'movies', 'train', 'journalist', 'navy', 'snapchat', 'podcast', 'coach', 'beer', 'board', 'writer', 'autistic', 'new', 'american', 'girl', 'political', 'advocate', 'addict', 'collector', 'fan', 'father', 'husband', 'dog', 'dad']
#
#
# top 50 words in topic 38
# -------------------------
# ['audio', 'collector', 'award', 'emmy', 'winner', 'gemini', 'dance', 'trainer', 'box', 'professional', 'fighter', 'videographer', 'club', 'choreographer', 'champion', 'business', 'transplant', 'native', 'actor', 'dad', 'comedian', 'chicago', 'lgbtq', 'enthusiast', 'currently', 'look', 'future', 'producer', 'university', 'tattoo', 'politics', 'district', 'best', 'football', 'ncaa', 'cat', 'retire', 'artist', 'denver', 'chill', 'rapper', 'respond', 'man', 'songwriter', 'record', 'sport', 'connecticut', 'account', 'owner', 'engineer']
#
#
# top 50 words in topic 39
# -------------------------
# ['soccer', 'picture', 'drag', 'american', 'angeles', 'proud', 'sweet', 'generation', 'pay', 'politics', 'everyday', 'meme', 'promoter', 'lifestyle', 'opinion', 'ass', 'best', 'public', 'doctor', 'alumnus', 'therapy', 'researcher', 'home', 'family', 'better', 'advocate', 'tree', 'place', 'university', 'world', 'entrepreneur', 'sport', 'creator', 'support', 'furry', 'chief', 'friends', 'red', 'actor', 'funny', 'snap', 'fanatic', 'like', 'cause', 'cat', 'insta', 'make', 'writer', 'good', 'podcast']
#
#
# top 50 words in topic 40
# -------------------------
# ['specialize', 'tattoo', 'wrestle', 'winner', 'data', 'angeles', 'base', 'heart', 'brooklyn', 'tongue', 'let', 'nyc', 'vaxxed', 'soft', 'advocate', 'tweeter', 'big', 'insta', 'personal', 'build', 'endorsement', 'things', 'cool', 'geek', 'deep', 'speaker', 'south', 'fight', 'instructor', 'professor', 'journalist', 'bear', 'account', 'like', 'latino', 'lookin', 'mom', 'social', 'california', 'movie', 'writer', 'partner', 'dicks', 'southern', 'nigga', 'animal', 'lover', 'write', 'book', 'currently']
#
#
# top 50 words in topic 41
# -------------------------
# ['consultant', 'follow', 'spirituality', 'cashapp', 'cars', 'horror', 'buy', 'liberal', 'pop', 'amateur', 'old', 'founder', 'profit', 'trans', 'seattle', 'speaker', 'champion', 'candidate', 'activist', 'radio', 'martial', 'health', 'jazz', 'deep', 'blue', 'entrepreneur', 'faith', 'strong', 'sense', 'university', 'dog', 'nerd', 'design', 'warzone', 'alumni', 'grandma', 'bully', 'politics', 'cancer', 'photographer', 'web', 'meme', 'queen', 'texas', 'art', 'virgo', 'artist', 'life', 'democrat', 'love']
#
#
# top 50 words in topic 42
# -------------------------
# ['health', 'amaze', 'comedy', 'foodie', 'trainer', 'fitness', 'diego', 'san', 'stay', 'style', 'wild', 'freedom', 'cocktails', 'follow', 'owner', 'entrepreneur', 'art', 'family', 'market', 'blood', 'taste', 'native', 'small', 'good', 'fan', 'business', 'god', 'love', 'lord', 'jesus', 'life', 'personal', 'science', 'mix', 'blogger', 'news', 'tech', 'advocate', 'football', 'make', 'nerd', 'master', 'fear', 'fight', 'stream', 'spirit', 'politics', 'free', 'gamer', 'light']
#
#
# top 50 words in topic 43
# -------------------------
# ['event', 'boy', 'grad', 'rip', 'singer', 'jazz', 'culture', 'podcaster', 'songwriter', 'single', 'angeles', 'talk', 'easy', 'model', 'band', 'nigga', 'dick', 'label', 'fun', 'brother', 'create', 'impact', 'double', 'university', 'major', 'digital', 'washington', 'good', 'family', 'video', 'artist', 'pro', 'president', 'web', 'marathon', 'man', 'design', 'sport', 'art', 'security', 'boys', 'life', 'work', 'love', 'anime', 'bad', 'everyday', 'retire', 'game', 'guy']
#
#
# top 50 words in topic 44
# -------------------------
# ['study', 'monitor', 'official', 'rest', 'event', 'raise', 'advocate', 'oakland', 'trump', 'record', 'thinker', 'water', 'composer', 'teacher', 'dreamer', 'family', 'student', 'man', 'scientist', 'singer', 'lover', 'entrepreneur', 'baseball', 'pro', 'rock', 'proud', 'fanatic', 'songwriter', 'dad', 'enthusiast', 'goth', 'dog', 'horror', 'anime', 'plant', 'metal', 'bitch', 'love', 'mom', 'currently', 'owner', 'wrestle', 'human', 'better', 'hot', 'label', 'support', 'hoe', 'diego', 'san']
#
#
# top 50 words in topic 45
# -------------------------
# ['anime', 'today', 'favorite', 'game', 'furry', 'new', 'dancer', 'avid', 'singer', 'actor', 'enthusiast', 'track', 'design', 'past', 'club', 'president', 'manager', 'media', 'engineer', 'black', 'director', 'creator', 'mom', 'author', 'world', 'entrepreneur', 'pansexual', 'audio', 'agency', 'disable', 'publish', 'help', 'crypto', 'best', 'life', 'raise', 'west', 'ones', 'photo', 'inquiries', 'radio', 'amateur', 'bear', 'writer', 'beautiful', 'available', 'wife', 'business', 'snapchat', 'owner']
#
#
# top 50 words in topic 46
# -------------------------
# ['profit', 'software', 'denver', 'worker', 'fox', 'report', 'award', 'company', 'short', 'tech', 'build', 'nerd', 'dad', 'trans', 'activist', 'favorite', 'brother', 'change', 'health', 'public', 'currently', 'fun', 'double', 'dallas', 'discord', 'time', 'dog', 'art', 'author', 'emmy', 'coach', 'growth', 'blm', 'gemini', 'board', 'win', 'employer', 'data', 'things', 'cat', 'game', 'engineer', 'texas', 'student', 'represent', 'phd', 'journalist', 'college', 'stuff', 'enthusiast']
#
#
# top 50 words in topic 47
# -------------------------
# ['traveler', 'husband', 'father', 'real', 'development', 'estate', 'native', 'grandma', 'town', 'musician', 'artist', 'mom', 'texas', 'vet', 'proud', 'smart', 'small', 'football', 'forever', 'state', 'mission', 'grand', 'writer', 'far', 'hockey', 'live', 'good', 'affiliate', 'guild', 'theme', 'game', 'twitch', 'war', 'value', 'video', 'programmer', 'engineer', 'athlete', 'financial', 'ass', 'mixer', 'smile', 'like', 'girl', 'youtuber', 'instagram', 'georgia', 'friends', 'democrat', 'family']
#
#
# top 50 words in topic 48
# -------------------------
# ['lawyer', 'sweet', 'hand', 'teach', 'phd', 'midwest', 'book', 'editor', 'bean', 'owner', 'wrestle', 'player', 'guitar', 'pro', 'media', 'native', 'art', 'end', 'culture', 'advocate', 'history', 'nfts', 'crypto', 'college', 'social', 'christian', 'tour', 'seattle', 'columbia', 'city', 'bay', 'black', 'fan', 'daddy', 'sex', 'speak', 'baseball', 'american', 'website', 'visit', 'film', 'hate', 'transit', 'update', 'state', 'writer', 'author', 'traffic', 'new', 'york']
#
#
# top 50 words in topic 49
# -------------------------
# ['education', 'humanity', 'nyc', 'florida', 'angeles', 'designer', 'photo', 'director', 'model', 'happen', 'good', 'track', 'publisher', 'insta', 'record', 'volunteer', 'text', 'mixer', 'dude', 'snap', 'york', 'ceo', 'win', 'opinions', 'like', 'nft', 'phil', 'school', 'bear', 'cub', 'cat', 'future', 'report', 'monitor', 'creator', 'emmy', 'producer', 'music', 'bay', 'count', 'daughter', 'life', 'art', 'official', 'francisco', 'san', 'save', 'account', 'fan', 'big']
#
#
# top 50 words in topic 50
# -------------------------
# ['brother', 'fear', 'kings', 'president', 'journalist', 'hockey', 'shark', 'spur', 'history', 'cook', 'proud', 'owner', 'practice', 'conservative', 'food', 'san', 'francisco', 'watch', 'wine', 'right', 'change', 'free', 'fun', 'mom', 'lookin', 'dancer', 'anti', 'beach', 'gift', 'tweet', 'weather', 'travel', 'sport', 'xbox', 'past', 'stand', 'advice', 'pay', 'retire', 'die', 'hospital', 'trump', 'read', 'love', 'family', 'bear', 'work', 'hard', 'ceo', 'founder']
#
#
# top 50 words in topic 51
# -------------------------
# ['bear', 'talk', 'chargers', 'retire', 'bully', 'freak', 'cal', 'aspire', 'relations', 'media', 'knight', 'bad', 'tip', 'expert', 'latest', 'cash', 'restaurant', 'drag', 'reader', 'lover', 'performer', 'comic', 'cartoon', 'build', 'book', 'follow', 'brand', 'atlanta', 'truck', 'private', 'brooklyn', 'coordinator', 'chicago', 'bisexual', 'fan', 'account', 'founder', 'travel', 'company', 'executive', 'credit', 'fuck', 'win', 'help', 'award', 'like', 'lot', 'people', 'producer', 'tweet']
#
#
# top 50 words in topic 52
# -------------------------
# ['veteran', 'design', 'male', 'vet', 'marry', 'york', 'media', 'mix', 'hop', 'historian', 'medical', 'navigate', 'break', 'guild', 'son', 'scientist', 'doctor', 'tech', 'modern', 'entrepreneur', 'travel', 'urban', 'entertainment', 'art', 'private', 'consultant', 'connoisseur', 'check', 'sun', 'guy', 'aries', 'lover', 'fan', 'big', 'designer', 'graphic', 'culture', 'philly', 'army', 'new', 'home', 'real', 'estate', 'rise', 'block', 'moon', 'owner', 'king', 'pizza', 'cashapp']
#
#
# top 50 words in topic 53
# -------------------------
# ['certify', 'personal', 'hop', 'block', 'seahawks', 'trainer', 'digital', 'jesus', 'think', 'shit', 'post', 'bean', 'cat', 'editor', 'sad', 'streamer', 'reporter', 'author', 'lot', 'voice', 'county', 'quality', 'profit', 'medical', 'care', 'high', 'assistant', 'web', 'tech', 'wild', 'gamer', 'blue', 'software', 'xxx', 'hand', 'geek', 'navy', 'big', 'unite', 'actor', 'ucla', 'health', 'developer', 'fanatic', 'fan', 'love', 'community', 'manager', 'sport', 'lover']
#
#
# top 50 words in topic 54
# -------------------------
# ['widow', 'hospital', 'care', 'cal', 'post', 'mind', 'marry', 'enthusiast', 'baby', 'trap', 'travel', 'red', 'plant', 'paint', 'knit', 'currently', 'metal', 'variety', 'big', 'food', 'hour', 'city', 'grow', 'chef', 'custom', 'design', 'designer', 'like', 'want', 'life', 'time', 'click', 'piece', 'comedy', 'sweet', 'nyc', 'health', 'mother', 'personal', 'joke', 'podcast', 'real', 'self', 'human', 'ass', 'cash', 'music', 'artist', 'content', 'creator']

# %%
# transform 
df_final = lda.transform(cv_fit)

print('Shape of the df_final:', df_final.shape)
# Out:
# Shape of the df_final: (1644, 55)

# %%
print('\nChecking the probabilitiy distribution of one text data belonging to the topic.\n')
print('Few words from 1st row:', df_new.new_tokens[0][:88],'\n')
print('Probability distribution:', df_final[0])
# Out:
# Checking the probabilitiy distribution of one text data belonging to the topic.
#
# Few words from 1st row: nerdy guy love art music wrestle comics poly
#
# Probability distribution: [0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.19548862 0.0025974  0.14927643 0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.1535443  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.36922311 0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974  0.0025974
#  0.0025974 ]

# %%
prob = df_final[0][df_final[0].argmax()].round(2)

print('Bio belonging to the topic', df_final[0].argmax(), 'with the probability of', prob)
# Out:
# Bio belonging to the topic 43 with the probability of 0.37

# %%
df_new['cluster'] = df_final.argmax(axis = 1)

df_new.head()
# Out:
#         user_id                                           user_bio  \
# 0  1.180000e+18  I'm a nerdy guy who loves art, music, wrestlin...
# 1  1.440000e+18  No worries Lil Ms Sunshine cause I don't mess ...
# 2  1.219720e+08  I am a huge sports and music fan. I graduated ...
# 3  1.390000e+18  This is not, nor endorsed by, any Government E...
# 4  2.349053e+07  I'm a writer and a cult film fanatic who loves...
#
#                                               tokens state     region  \
# 0       nerdy guy love art music wrestle comics poly    OH    Midwest
# 1  worry lil sunshine cause mess woman moon civil...    PA  Northeast
# 2  huge sport music fan graduate regis university...    CO       West
# 3  endorse government entity project guarantee wa...    WA       West
# 4             writer cult film fanatic love politics    UT       West
#
#                                            ls_tokens  \
# 0  [nerdy, guy, love, art, music, wrestle, comics...
# 1  [worry, sunshine, cause, mess, woman, moon, ci...
# 2  [sport, music, fan, graduate, regis, universit...
# 3  [endorse, government, entity, project, guarant...
# 4      [writer, cult, film, fanatic, love, politics]
#
#                                           new_tokens  cluster
# 0       nerdy guy love art music wrestle comics poly       43
# 1  worry sunshine cause mess woman moon civil rig...       52
# 2  sport music fan graduate regis university live...       38
# 3  endorse government entity project guarantee wa...        9
# 4             writer cult film fanatic love politics       21

# %%
# creating a dictionary with key as topic numbers and value as topic names
#Joscelin used random genres here to see if everything is working

topic_label = {0:'punkrock', 1:'chill', 2:'punk', 3:'latino', 4:'happy', 5:'rock',6:'rnb', 7:'edm',8:'goth',9:'happy', 10:'gospel', 11:'house', 12:'edm', 13:'songwriter', 
14:'latinio', 15:'comedy', 16:'anime', 17:'jrock', 18:'country', 19:'electronic', 20:'disco', 21:'gospel', 22:'ambient', 23:'gospel', 24:'jazz', 25:'pop', 26:'honkytonk',
27:'newage', 28:'latino', 29:'heavymetal', 30:'pop', 31:'romance', 32:'acoustic', 33:'newage', 34:'afrobeat', 35:'party', 36:'rockabilly', 37:'punkrock', 38:'jazz', 
39:'altrock', 40:'soul', 41:'funk', 42:'newage', 43:'groove', 44:'minimaltechno', 45:'acoustic', 46:'dancehall', 47:'heavymetal', 48:'club', 49:'breakbeat', 50:'punkrock',
51:'country', 52:'reggae', 53:'anime', 54:'rockabilly'}

# mapping the dictionary with the dataframe to get the labels.
df_new['genre'] = df_new['cluster'].map(topic_label)

# head of the dataframe
df_new.head()
# Out:
#         user_id                                           user_bio  \
# 0  1.180000e+18  I'm a nerdy guy who loves art, music, wrestlin...
# 1  1.440000e+18  No worries Lil Ms Sunshine cause I don't mess ...
# 2  1.219720e+08  I am a huge sports and music fan. I graduated ...
# 3  1.390000e+18  This is not, nor endorsed by, any Government E...
# 4  2.349053e+07  I'm a writer and a cult film fanatic who loves...
#
#                                               tokens state     region  \
# 0       nerdy guy love art music wrestle comics poly    OH    Midwest
# 1  worry lil sunshine cause mess woman moon civil...    PA  Northeast
# 2  huge sport music fan graduate regis university...    CO       West
# 3  endorse government entity project guarantee wa...    WA       West
# 4             writer cult film fanatic love politics    UT       West
#
#                                            ls_tokens  \
# 0  [nerdy, guy, love, art, music, wrestle, comics...
# 1  [worry, sunshine, cause, mess, woman, moon, ci...
# 2  [sport, music, fan, graduate, regis, universit...
# 3  [endorse, government, entity, project, guarant...
# 4      [writer, cult, film, fanatic, love, politics]
#
#                                           new_tokens  cluster   genre
# 0       nerdy guy love art music wrestle comics poly       43  groove
# 1  worry sunshine cause mess woman moon civil rig...       52  reggae
# 2  sport music fan graduate regis university live...       38    jazz
# 3  endorse government entity project guarantee wa...        9   happy
# 4             writer cult film fanatic love politics       21  gospel
